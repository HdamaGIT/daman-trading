# %%
import requests
import pandas as pd

# %%
# -------------- CONFIG --------------
CLIENT_ID = "632f59ffb300474e8c2696f44a359090"
CLIENT_SECRET = "RbK5nlZBW3lKXv40W5e7WkKRp24RLIjh"
REGION = "eu"

# %%
REALM_SLUG = "soulseeker"
CHAR_NAME = "Sphere"
NAMESPACE = f"profile-classic1x-{REGION}"

# %%
# ------------------------------------
def get_access_token():
    url = f"https://eu.battle.net/oauth/token"
    resp = requests.post(url, data={"grant_type": "client_credentials"},
                         auth=(CLIENT_ID, CLIENT_SECRET))
    resp.raise_for_status()
    return resp.json()["access_token"]

def get_character_gear(token, character_name):
    url = (
        f"https://{REGION}.api.blizzard.com/profile/wow/character/"
        f"{REALM_SLUG}/{character_name.lower()}/equipment"
    )
    params = {"namespace": NAMESPACE, "locale": "en_GB"}
    headers = {"Authorization": f"Bearer {token}"}
    response = requests.get(url, headers=headers, params=params)
    
    if response.status_code == 404:
        print(f"Character '{character_name}' not found.")
        return []

    response.raise_for_status()
    gear_data = response.json()

    gear_list = []
    for item in gear_data.get("equipped_items", []):
        gear_list.append({
            "Name": character_name,
            "Slot": item["slot"]["name"],
            "Item": item["name"]
        })

    return gear_list

def get_raid_gear_dataframe(raider_names):
    token = get_access_token()
    all_gear = []

    for name in raider_names:
        try:
            gear = get_character_gear(token, name)
            all_gear.extend(gear)
        except Exception as e:
            print(f"Error retrieving gear for {name}: {e}")

    return pd.DataFrame(all_gear)

# %%
# Example usage:
raiders = ["Sphere", "Oxigodx", "Amozuggerz","Brezhyisleep","Fiorin","Qxisbkbk","Zeyv","Cptn","Eleenbk","Thotiana","Vástago","Lastzug","Ethor","Ibbernezer", "Loparn"]
df_gear = get_raid_gear_dataframe(raiders)

# %%
df_gear.head()
# Out:
#      Name       Slot                   Item
# 0  Sphere       Head         Lionheart Helm
# 1  Sphere       Neck   Onyxia Tooth Pendant
# 2  Sphere  Shoulders  Bloodsoaked Pauldrons
# 3  Sphere      Chest       Cadaverous Armor
# 4  Sphere      Waist       Onslaught Girdle

# %%
df_gear.pivot(index='Name',columns='Slot',values='Item')
# Out:
# Slot                             Back                              Chest  \
# Name
# Amozuggerz    Cloak of Draconic Might             Savage Gladiator Chain
# Brezhyisleep  Stoneskin Gargoyle Cape                   Cadaverous Armor
# Cptn                    Puissant Cape             Savage Gladiator Chain
# Eleenbk       Cape of the Black Baron  Zandalar Vindicator's Breastplate
# Ethor         Stoneskin Gargoyle Cape               Breastplate of Valor
# Fiorin             Might of the Tribe            Deathdealer Breastplate
# Ibbernezer    Cape of the Black Baron             Savage Gladiator Chain
# Lastzug       Cape of the Black Baron                   Cadaverous Armor
# Loparn               Eskhandar's Pelt  Zandalar Vindicator's Breastplate
# Lastzug                    Brutality Blade       The Eye of Hakkar
# Loparn                Bloodlord's Defender     Beads of Ogre Might
# Oxigodx                Empyrean Demolisher    Onyxia Tooth Pendant
# Qxisbkbk                        Blackguard     Beads of Ogre Might
# Sphere                 Empyrean Demolisher    Onyxia Tooth Pendant
# Thotiana           Vis'kag the Bloodletter    Onyxia Tooth Pendant
# Vástago                       Spineshatter       The Eye of Hakkar
# Zeyv                   Empyrean Demolisher    Onyxia Tooth Pendant
#
# Slot                        Off Hand                       Ranged  \
# Name
# Amozuggerz              Mirah's Song                      Riphook
# Brezhyisleep         Brutality Blade     Skull Splitting Crossbow
# Cptn                    Deathbringer  Archstrike Bow of the Tiger
# Eleenbk                 Mirah's Song                  Satyr's Bow
# Ethor                     Blackguard                  Satyr's Bow
# Fiorin                  Mirah's Song     Skull Splitting Crossbow
# Ibbernezer                Blackguard         Blastershot Launcher
# Lastzug                 Mirah's Song                      Riphook
# Loparn                    Blackguard                  Satyr's Bow
# Oxigodx              Brutality Blade                  Satyr's Bow
# Qxisbkbk      Aegis of the Blood God                      Riphook
# Sphere                  Mirah's Song                      Riphook
# Thotiana                Mirah's Song                  Satyr's Bow
# Vástago                   Blackguard            Malgen's Long Bow
# Zeyv                      Blackguard         Blastershot Launcher
#
# Slot                                   Ring 1  \
# Name
# Amozuggerz         Master Dragonslayer's Ring
# Brezhyisleep                Quick Strike Ring
# Cptn                          Painweaver Band
# Eleenbk                       Painweaver Band
# Ethor                         Blackstone Ring
# Fiorin             Master Dragonslayer's Ring
# Ibbernezer         Master Dragonslayer's Ring
# Lastzug            Master Dragonslayer's Ring
# Loparn                           Magni's Will
# Oxigodx               Circle of Applied Force
# Qxisbkbk                         Magni's Will
# Sphere                           Magni's Will
# Thotiana                          Seal of Jin
# Vástago       Seal of the Gurubashi Berserker
# Zeyv          Seal of the Gurubashi Berserker
#
# Slot                                   Ring 2               Shirt  \
# Name
# Amozuggerz                  Quick Strike Ring  Formal White Shirt
# Brezhyisleep       Master Dragonslayer's Ring                 NaN
# Cptn               Master Dragonslayer's Ring                 NaN
# Eleenbk                          Magni's Will                 NaN
# Ethor                            Magni's Will  Formal White Shirt
# Fiorin                        Blackstone Ring  Formal White Shirt
# Ibbernezer    Seal of the Gurubashi Berserker   Stylish Red Shirt
# Lastzug       Seal of the Gurubashi Berserker     Red Linen Shirt
# Loparn                        Blackstone Ring     Red Linen Shirt
# Oxigodx            Master Dragonslayer's Ring                 NaN
# Qxisbkbk      Seal of the Gurubashi Berserker                 NaN
# Sphere        Seal of the Gurubashi Berserker                 NaN
# Thotiana      Seal of the Gurubashi Berserker                 NaN
# Vástago            Master Dragonslayer's Ring  Formal White Shirt
# Zeyv               Master Dragonslayer's Ring      Sawbones Shirt
