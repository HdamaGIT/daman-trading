# %%
# %load_ext autoreload
# %autoreload 2
from config.config import inputs
from master_func import master

# %%
from datetime import datetime

# %%
################################################################################
################################################################################

# %%
# Choose modules to run
finviz = False
yahoo_extract = True
data_prep = False
meanreversion = False
strategy = False
run_backtest = False
run_forwardstest = False
montecarlo = False

# %%
start_time = datetime.now()
print("start time: " + str(start_time))

input_vars = inputs()
master(input_vars, finviz=finviz, yahoo_extract=yahoo_extract, data_prep=data_prep, meanreversion=meanreversion, strategy=strategy, run_backtest=run_backtest, run_forwardstest=run_forwardstest, montecarlo=montecarlo)
# Out:
# start time: 2023-07-30 20:36:34.861751
# Process: Historic data saved to outputs/finviz_tickers.csv.
# changes successfully committed to finviz_tickers!

# %%
################################################################################
################################################################################
