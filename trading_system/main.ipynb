# %%
from datetime import datetime
import matplotlib as plt
import seaborn as sns
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2
# from config import AppConfig
from main import main
from backtesting.evaluate_plot import plot_prices_positions_and_portfolio
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
################################################################################
################################################################################
################################################################################

# %%
# # Initialize the app configuration
# config = AppConfig(system_mode='development')
# # 
# # Example usage
# print(config.summary())

# %%
dic = main()
# Out:
# 2024-10-13 21:57:29 - root - INFO - Starting the trading system...
# 2024-10-13 21:57:29 - root - INFO - Config loaded successfully.
# [*********************100%***********************]  1 of 1 completed
# 2024-10-13 21:57:29 - root - INFO - Data fetched successfully for BTC-GBP.
# [*********************100%***********************]  1 of 1 completed
# 2024-10-13 21:57:29 - root - INFO - Data fetched successfully for ETH-GBP.
# [*********************100%***********************]  1 of 1 completed
# 2024-10-13 21:57:29 - root - INFO - Data fetched successfully for ETH-BTC.
# 2024-10-13 21:57:29 - root - INFO - Data loaded successfully.
# 2024-10-13 21:57:29 - root - INFO - Calculating indicators...
# 2024-10-13 21:57:29 - root - INFO - Generating all signals...
# Buy signal triggered at 59 with price 33260.2109375
# Entered long position at 59 with price 33260.2109375
# Sell signal triggered at 64 with price 29080.162109375
# Exited position at 64 with price 29080.162109375
# Buy signal triggered at 82 with price 33318.2109375
# Entered long position at 82 with price 33318.2109375
# Sell signal triggered at 94 with price 34837.078125
# Exited position at 94 with price 34837.078125
# Buy signal triggered at 223 with price 20098.283203125
# Entered long position at 223 with price 20098.283203125
# Sell signal triggered at 228 with price 19372.962890625
# Exited position at 228 with price 19372.962890625
# Buy signal triggered at 301 with price 17926.103515625
# Entered long position at 301 with price 17926.103515625
# Sell signal triggered at 306 with price 18092.22265625
# Exited position at 306 with price 18092.22265625
# Buy signal triggered at 307 with price 18582.810546875
# Entered long position at 307 with price 18582.810546875
# Sell signal triggered at 312 with price 13969.369140625
# Exited position at 312 with price 13969.369140625
# Buy signal triggered at 376 with price 15445.3046875
# Entered long position at 376 with price 15445.3046875
# Sell signal triggered at 381 with price 17227.423828125
# Exited position at 381 with price 17227.423828125
# Buy signal triggered at 382 with price 16756.1953125
# Entered long position at 382 with price 16756.1953125
# Sell signal triggered at 387 with price 18526.525390625
# Exited position at 387 with price 18526.525390625
# Buy signal triggered at 388 with price 18356.43359375
# Entered long position at 388 with price 18356.43359375
# Sell signal triggered at 393 with price 19172.357421875
# Exited position at 393 with price 19172.357421875
# Buy signal triggered at 412 with price 20396.548828125
# Entered long position at 412 with price 20396.548828125
# Sell signal triggered at 417 with price 20078.673828125
# Exited position at 417 with price 20078.673828125
# Buy signal triggered at 438 with price 20365.5
# Entered long position at 438 with price 20365.5
# Sell signal triggered at 443 with price 23006.376953125
# Exited position at 443 with price 23006.376953125
# Buy signal triggered at 444 with price 22622.966796875
# Entered long position at 444 with price 22622.966796875
# Sell signal triggered at 449 with price 22486.875
# Exited position at 449 with price 22486.875
# Buy signal triggered at 466 with price 24324.951171875
# Entered long position at 466 with price 24324.951171875
# Sell signal triggered at 471 with price 24447.87890625
# Exited position at 471 with price 24447.87890625
# Buy signal triggered at 473 with price 24465.37890625
# Entered long position at 473 with price 24465.37890625
# Sell signal triggered at 478 with price 22165.677734375
# Exited position at 478 with price 22165.677734375
# Buy signal triggered at 538 with price 23466.423828125
# Entered long position at 538 with price 23466.423828125
# Sell signal triggered at 543 with price 24077.2265625
# Exited position at 543 with price 24077.2265625
# Buy signal triggered at 546 with price 23985.56640625
# Entered long position at 546 with price 23985.56640625
# Sell signal triggered at 551 with price 24018.37109375
# Exited position at 551 with price 24018.37109375
# Buy signal triggered at 636 with price 22140.9140625
# Entered long position at 636 with price 22140.9140625
# Sell signal triggered at 641 with price 22712.21484375
# Exited position at 641 with price 22712.21484375
# Buy signal triggered at 644 with price 22835.91796875
# Entered long position at 644 with price 22835.91796875
# Sell signal triggered at 649 with price 21821.1640625
# Exited position at 649 with price 21821.1640625
# Buy signal triggered at 655 with price 23333.166015625
# Entered long position at 655 with price 23333.166015625
# Sell signal triggered at 660 with price 24659.271484375
# Exited position at 660 with price 24659.271484375
# Buy signal triggered at 661 with price 27011.0703125
# Entered long position at 661 with price 27011.0703125
# Sell signal triggered at 666 with price 28108.150390625
# Exited position at 666 with price 28108.150390625
# Buy signal triggered at 670 with price 29090.546875
# Entered long position at 670 with price 29090.546875
# Sell signal triggered at 675 with price 28384.369140625
# Exited position at 675 with price 28384.369140625
# Buy signal triggered at 679 with price 30527.677734375
# Entered long position at 679 with price 30527.677734375
# Sell signal triggered at 684 with price 30495.119140625
# Exited position at 684 with price 30495.119140625
# Buy signal triggered at 703 with price 33228.71875
# Entered long position at 703 with price 33228.71875
# Sell signal triggered at 710 with price 32854.87890625
# Exited position at 710 with price 32854.87890625
# Buy signal triggered at 738 with price 36863.765625
# Entered long position at 738 with price 36863.765625
# Sell signal triggered at 743 with price 33612.41796875
# Exited position at 743 with price 33612.41796875
# Buy signal triggered at 768 with price 35098.79296875
# Entered long position at 768 with price 35098.79296875
# Sell signal triggered at 784 with price 40009.44921875
# Exited position at 784 with price 40009.44921875
# Buy signal triggered at 788 with price 45017.18359375
# Entered long position at 788 with price 45017.18359375
# Sell signal triggered at 795 with price 50218.5625
# Exited position at 795 with price 50218.5625
# Buy signal triggered at 796 with price 51906.0703125
# Entered long position at 796 with price 51906.0703125
# Sell signal triggered at 806 with price 51303.98046875
# Exited position at 806 with price 51303.98046875
# Buy signal triggered at 871 with price 56214.8671875
# Entered long position at 871 with price 56214.8671875
# Sell signal triggered at 877 with price 53806.3671875
# Exited position at 877 with price 53806.3671875
# Buy signal triggered at 887 with price 55560.75
# Entered long position at 887 with price 55560.75
# Sell signal triggered at 892 with price 54623.09765625
# Exited position at 892 with price 54623.09765625
# Buy signal triggered at 934 with price 52263.19921875
# Entered long position at 934 with price 52263.19921875
# Sell signal triggered at 939 with price 52750.4375
# Exited position at 939 with price 52750.4375
# Buy signal triggered at 1000 with price 48607.703125
# Entered long position at 1000 with price 48607.703125
# Sell signal triggered at 1005 with price 45831.37890625
# Exited position at 1005 with price 45831.37890625
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:70: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:83: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:77: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:86: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/strategy/signal_generation.py:90: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 2024-10-13 21:57:30 - root - INFO - Momentum signals generated for ETH-BTC.
# 2024-10-13 21:57:30 - root - INFO - Applying strategy...
# 2024-10-13 21:57:30 - root - INFO - Strategy completed successfully.
# 2024-10-13 21:57:30 - root - INFO - Strategy signals generated successfully.
# 2024-10-13 21:57:30 - root - INFO - Backtesting completed successfully.
# 2024-10-13 21:57:30 - root - INFO - Trading system completed successfully.
# Buy signal triggered at 87 with price 0.07167299836874008
# Entered long position at 87 with price 0.07167299836874008
# Sell signal triggered at 92 with price 0.07583600282669067
# Exited position at 92 with price 0.07583600282669067
# Buy signal triggered at 93 with price 0.07552599906921387
# Entered long position at 93 with price 0.07552599906921387
# Sell signal triggered at 98 with price 0.07624500244855881
# Exited position at 98 with price 0.07624500244855881
# Buy signal triggered at 100 with price 0.07542800158262253
# Entered long position at 100 with price 0.07542800158262253
# Sell signal triggered at 105 with price 0.07575400173664093
# Exited position at 105 with price 0.07575400173664093
# Buy signal triggered at 197 with price 0.06442099809646606
# Entered long position at 197 with price 0.06442099809646606
# Sell signal triggered at 202 with price 0.06768199801445007
# Exited position at 202 with price 0.06768199801445007
# Buy signal triggered at 205 with price 0.06766200065612793
# Entered long position at 205 with price 0.06766200065612793
# Sell signal triggered at 210 with price 0.07169199734926224
# Exited position at 210 with price 0.07169199734926224
# Buy signal triggered at 221 with price 0.0773250013589859
# Entered long position at 221 with price 0.0773250013589859
# Sell signal triggered at 228 with price 0.07854799926280975
# Exited position at 228 with price 0.07854799926280975
# Buy signal triggered at 248 with price 0.08290600031614304
# Entered long position at 248 with price 0.08290600031614304
# Sell signal triggered at 254 with price 0.07660800218582153
# Exited position at 254 with price 0.07660800218582153
# Buy signal triggered at 298 with price 0.07542300224304199
# Entered long position at 298 with price 0.07542300224304199
# Sell signal triggered at 303 with price 0.07673399895429611
# Exited position at 303 with price 0.07673399895429611
# Buy signal triggered at 305 with price 0.0753839984536171
# Entered long position at 305 with price 0.0753839984536171
# Sell signal triggered at 310 with price 0.07613500207662582
# Exited position at 310 with price 0.07613500207662582
# Buy signal triggered at 368 with price 0.07451300323009491
# Entered long position at 368 with price 0.07451300323009491
# Sell signal triggered at 373 with price 0.07684899866580963
# Exited position at 373 with price 0.07684899866580963
# Buy signal triggered at 374 with price 0.0766109973192215
# Entered long position at 374 with price 0.0766109973192215
# Sell signal triggered at 379 with price 0.07434999942779541
# Exited position at 379 with price 0.07434999942779541
# Buy signal triggered at 435 with price 0.07187400013208389
# Entered long position at 435 with price 0.07187400013208389
# Sell signal triggered at 440 with price 0.06694100052118301
# Exited position at 440 with price 0.06694100052118301
# Buy signal triggered at 472 with price 0.07050299644470215
# Entered long position at 472 with price 0.07050299644470215
# Sell signal triggered at 477 with price 0.06737899780273438
# Exited position at 477 with price 0.06737899780273438
# Buy signal triggered at 511 with price 0.06843899935483932
# Entered long position at 511 with price 0.06843899935483932
# Sell signal triggered at 516 with price 0.06885500252246857
# Exited position at 516 with price 0.06885500252246857
# Buy signal triggered at 518 with price 0.06998500227928162
# Entered long position at 518 with price 0.06998500227928162
# Sell signal triggered at 523 with price 0.06954699754714966
# Exited position at 523 with price 0.06954699754714966
# Buy signal triggered at 742 with price 0.05898300185799599
# Entered long position at 742 with price 0.05898300185799599
# Sell signal triggered at 747 with price 0.059154000133275986
# Exited position at 747 with price 0.059154000133275986
# Buy signal triggered at 781 with price 0.057649001479148865
# Entered long position at 781 with price 0.057649001479148865
# Sell signal triggered at 786 with price 0.06017100065946579
# Exited position at 786 with price 0.06017100065946579
# Buy signal triggered at 873 with price 0.054058000445365906
# Entered long position at 873 with price 0.054058000445365906
# Sell signal triggered at 878 with price 0.056095000356435776
# Exited position at 878 with price 0.056095000356435776
# Buy signal triggered at 906 with price 0.055590998381376266
# Entered long position at 906 with price 0.055590998381376266
# Sell signal triggered at 911 with price 0.055396001785993576
# Exited position at 911 with price 0.055396001785993576

# %%
dic['evaluation_summary']
# Out:
# {'Number of Trading Days': 1016,
#  'Number of Trades': 114,
#  'Average Trades Per Month': 3.0,
#  'Start Portfolio Value': '£1,000',
#  'End Portfolio Value': '£407',
#  'Profit/Loss': '£-593',
#  'Profit Percentage': '-59.0%',
#  'Sharpe Ratio': -0.8,
#  'Sortino Ratio': -0.82,
#  'Volatility': '25.33%',
#  'Max Drawdown': '-59.29%',
#  'Average Drawdown Length': '478.5 days',
#  'Fees Paid': '£0.00',
#  'Win Rate': '50.0%',
#  'Profit Factor': inf,
#  'BTC-GBP Hold Final Value': '£1,356',
#  'BTC-GBP Hold Profit/Loss': '£356',
#  'BTC-GBP Hold Profit Percentage': '36.0%',
#  'ETH-GBP Hold Final Value': '£669',
#  'ETH-GBP Hold Profit/Loss': '£-331',
#  'ETH-GBP Hold Profit Percentage': '-33.0%'}

# %%
plot_prices_positions_and_portfolio(dic)

# %%
portfolio_values_df = pd.DataFrame(dic['backtest_details']['portfolio_value'], columns=['Portfolio Value'])
sns.lineplot(portfolio_values_df)
# Out:
# <Axes: >

# %%
################################################################################
################################PLOTSPLOTSPLOTS#################################
################################################################################

# %%
def plot(df):
    sns.lineplot(data=df, x='Date', y='Close')
    sns.lineplot(data=df, x='Date', y='short_sma')
    sns.lineplot(data=df, x='Date', y='long_sma')

# %%
plot(pd.DataFrame(dic['ETH-BTC']))

# %%
plot(pd.DataFrame(dic['BTC-GBP']))

# %%
plot(pd.DataFrame(dic['ETH-GBP']))

# %%
dic.keys()
# Out:
# dict_keys(['BTC-GBP', 'ETH-GBP', 'ETH-BTC', 'combined_position', 'backtest_details', 'evaluation_summary'])

# %%
dic['backtest_details']['trades']
# Out:
# [{'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02955737649895739,
#   'price': 33426.511992187494,
#   'transaction_cost': 12.0,
#   'time_point': 59},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02955737649895739,
#   'price': 29440.128017578125,
#   'time_point': 62},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02686586394494392,
#   'price': 32000.864531249998,
#   'transaction_cost': 10.442075375916728,
#   'time_point': 67},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02686586394494392,
#   'price': 29948.5283203125,
#   'time_point': 68},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.025262691288589805,
#   'price': 31466.875839843746,
#   'transaction_cost': 9.655117046457786,
#   'time_point': 74},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.025262691288589805,
#   'price': 31187.581220703123,
#   'time_point': 78},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.3288120671609469,
#   'price': 2367.393801269531,
#   'transaction_cost': 9.454586836997326,
#   'time_point': 82},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.3288120671609469,
#   'price': 2299.5601440429687,
#   'time_point': 103},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.3403496303069779,
#   'price': 2194.947725830078,
#   'transaction_cost': 9.07347749428432,
#   'time_point': 125},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.3403496303069779,
#   'price': 2032.2432885742187,
#   'time_point': 127},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.3570950912284165,
#   'price': 1913.700831298828,
#   'transaction_cost': 8.300079023520867,
#   'time_point': 129},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.3570950912284165,
#   'price': 1685.3100360107421,
#   'time_point': 130},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5255096396249397,
#   'price': 1131.4619274902343,
#   'transaction_cost': 7.221791292689062,
#   'time_point': 197},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5255096396249397,
#   'price': 1338.0199340820313,
#   'time_point': 213},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.03602281930109417,
#   'price': 19285.127548828124,
#   'transaction_cost': 8.437708480445206,
#   'time_point': 220},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.03602281930109417,
#   'price': 19513.862265625,
#   'time_point': 221},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.45569448528060325,
#   'price': 1524.067164916992,
#   'transaction_cost': 8.435332011132594,
#   'time_point': 221},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.45569448528060325,
#   'price': 1514.1018969726563,
#   'time_point': 228},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.48508930450331955,
#   'price': 1405.2840655517577,
#   'transaction_cost': 8.279614615240074,
#   'time_point': 247},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.48508930450331955,
#   'price': 1458.747734375,
#   'time_point': 254},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5168587362459908,
#   'price': 1352.6547967529295,
#   'transaction_cost': 8.491475086965142,
#   'time_point': 298},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5168587362459908,
#   'price': 1147.9963110351562,
#   'time_point': 311},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5726513449952866,
#   'price': 1023.7148739624022,
#   'transaction_cost': 7.120223070440282,
#   'time_point': 332},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5726513449952866,
#   'price': 1004.3292181396484,
#   'time_point': 340},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5399052839291578,
#   'price': 1052.4603643798828,
#   'transaction_cost': 6.901565731028811,
#   'time_point': 341},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5399052839291578,
#   'price': 1027.984638671875,
#   'time_point': 343},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5235268382583139,
#   'price': 1047.4232189941406,
#   'transaction_cost': 6.6601720586034165,
#   'time_point': 368},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5235268382583139,
#   'price': 1180.8988427734375,
#   'time_point': 377},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.0327594096320398,
#   'price': 18645.435234375,
#   'transaction_cost': 7.418786849520955,
#   'time_point': 390},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.0327594096320398,
#   'price': 18401.873974609374,
#   'time_point': 394},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.029738672888254013,
#   'price': 20027.81077148437,
#   'transaction_cost': 7.23401433037681,
#   'time_point': 418},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.029738672888254013,
#   'price': 19328.543515625,
#   'time_point': 419},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.45866190383510885,
#   'price': 1238.1834320068358,
#   'transaction_cost': 6.8976627962106605,
#   'time_point': 435},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.45866190383510885,
#   'price': 1374.0906274414062,
#   'time_point': 437},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02807226760887364,
#   'price': 22181.325556640622,
#   'transaction_cost': 7.562916278691056,
#   'time_point': 451},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02807226760887364,
#   'price': 22519.28697265625,
#   'time_point': 454},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.36350251861692473,
#   'price': 1718.2313983154295,
#   'transaction_cost': 7.586009403089139,
#   'time_point': 471},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.36350251861692473,
#   'price': 1466.8349029541016,
#   'time_point': 479},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.3636187337214909,
#   'price': 1448.7696990966795,
#   'transaction_cost': 6.39837817942834,
#   'time_point': 498},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.3636187337214909,
#   'price': 1452.2667523193359,
#   'time_point': 502},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.35762585256117996,
#   'price': 1458.8837384033202,
#   'transaction_cost': 6.336856770050148,
#   'time_point': 503},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.35762585256117996,
#   'price': 1457.2424810791015,
#   'time_point': 525},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.0218325619896762,
#   'price': 23583.75594726562,
#   'transaction_cost': 6.253771016211394,
#   'time_point': 538},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.0218325619896762,
#   'price': 23956.8404296875,
#   'time_point': 543},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.022014141074298037,
#   'price': 23474.12654296875,
#   'transaction_cost': 6.2764704450952005,
#   'time_point': 585},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.022014141074298037,
#   'price': 22853.13279296875,
#   'time_point': 592},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.37401960327145956,
#   'price': 1328.9543646240234,
#   'transaction_cost': 6.03710507152897,
#   'time_point': 597},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.37401960327145956,
#   'price': 1276.96978515625,
#   'time_point': 599},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.35661646983750306,
#   'price': 1323.2153631591796,
#   'transaction_cost': 5.731340789205379,
#   'time_point': 604},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.35661646983750306,
#   'price': 1303.7908166503905,
#   'time_point': 605},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02105082088136369,
#   'price': 21822.134238281247,
#   'transaction_cost': 5.57943934128501,
#   'time_point': 630},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02105082088136369,
#   'price': 22835.86798828125,
#   'time_point': 639},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02100765827286284,
#   'price': 22608.19341796875,
#   'transaction_cost': 5.768565200301308,
#   'time_point': 643},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02100765827286284,
#   'price': 22721.73837890625,
#   'time_point': 644},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.020536068635669945,
#   'price': 22964.59743164062,
#   'transaction_cost': 5.72796618275346,
#   'time_point': 645},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.020536068635669945,
#   'price': 22177.06916015625,
#   'time_point': 648},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.01918839587416856,
#   'price': 23449.831845703124,
#   'transaction_cost': 5.465157772931616,
#   'time_point': 655},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.01918839587416856,
#   'price': 26876.0149609375,
#   'time_point': 661},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.013752914104375005,
#   'price': 37048.084453125,
#   'transaction_cost': 6.188491375086548,
#   'time_point': 738},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.013752914104375005,
#   'price': 36403.55583984375,
#   'time_point': 740},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.24850477537729593,
#   'price': 1990.49340637207,
#   'transaction_cost': 6.007859718710282,
#   'time_point': 742},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.24850477537729593,
#   'price': 1756.7185333251953,
#   'time_point': 753},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.012683426749912553,
#   'price': 34006.13396484375,
#   'transaction_cost': 5.238635334301325,
#   'time_point': 760},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.012683426749912553,
#   'price': 34014.60359375,
#   'time_point': 767},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.1776866809154492,
#   'price': 2398.855502929687,
#   'transaction_cost': 5.177060797303685,
#   'time_point': 781},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.1776866809154492,
#   'price': 2660.695831298828,
#   'time_point': 789},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.15370790126688122,
#   'price': 3038.861143798828,
#   'transaction_cost': 5.673242534268729,
#   'time_point': 797},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.15370790126688122,
#   'price': 3095.236574707031,
#   'time_point': 802},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.00858081462836862,
#   'price': 54779.550703124994,
#   'transaction_cost': 5.709147813872496,
#   'time_point': 805},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.00858081462836862,
#   'price': 51047.46056640625,
#   'time_point': 806},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.008159378996422969,
#   'price': 53039.876074218744,
#   'transaction_cost': 5.2563455564314685,
#   'time_point': 868},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.008159378996422969,
#   'price': 54906.17939453125,
#   'time_point': 872},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.1499098971477248,
#   'price': 2952.602406005859,
#   'transaction_cost': 5.376003923106839,
#   'time_point': 873},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.1499098971477248,
#   'price': 2969.9326489257815,
#   'time_point': 886},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.007877704575414441,
#   'price': 55838.55374999999,
#   'transaction_cost': 5.342667575233604,
#   'time_point': 887},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.007877704575414441,
#   'price': 54445.62654296875,
#   'time_point': 891},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.15171217227504388,
#   'price': 2793.181827392578,
#   'transaction_cost': 5.14687873594621,
#   'time_point': 903},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.15171217227504388,
#   'price': 2707.0772607421873,
#   'time_point': 913},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.007966004413219154,
#   'price': 50937.48281249999,
#   'transaction_cost': 4.928358860922871,
#   'time_point': 936},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.007966004413219154,
#   'price': 50024.46453125,
#   'time_point': 943},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.008229364403651122,
#   'price': 47842.475390625,
#   'transaction_cost': 4.781941262698351,
#   'time_point': 995},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.008229364403651122,
#   'price': 45602.222011718746,
#   'time_point': 1005}]

# %%
dic['combined_position']
# Out:
# {'final_signal': ['BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'ETH',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC',
#   'ETH',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC']}

# %%
dic.keys()
# Out:
# dict_keys(['BTC-GBP', 'ETH-GBP', 'ETH-BTC', 'combined_position', 'backtest_details', 'evaluation_summary'])
