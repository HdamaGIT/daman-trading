# %%
from datetime import datetime
import matplotlib as plt
import seaborn as sns
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2
# from config import AppConfig
from main import main
from backtesting.evaluate_plot import plot_prices_positions_and_portfolio
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
################################################################################
################################################################################
################################################################################

# %%
# # Initialize the app configuration
# config = AppConfig(system_mode='development')
# # 
# # Example usage
# print(config.summary())

# %%
dic = main()
# Out:
# 2024-10-05 20:03:34 - root - INFO - Starting the trading system...
# 2024-10-05 20:03:34 - root - INFO - Config loaded successfully.
# [*********************100%***********************]  1 of 1 completed
# 2024-10-05 20:03:34 - root - INFO - Data fetched successfully for BTC-GBP.
# [*********************100%***********************]  1 of 1 completed
# 2024-10-05 20:03:35 - root - INFO - Data fetched successfully for ETH-GBP.
# [*********************100%***********************]  1 of 1 completed
# 2024-10-05 20:03:35 - root - INFO - Data fetched successfully for ETH-BTC.
# 2024-10-05 20:03:35 - root - INFO - Data loaded successfully.
# 2024-10-05 20:03:35 - root - INFO - Calculating indicators...
# 2024-10-05 20:03:35 - root - INFO - Generating all signals...
# 2024-10-05 20:03:35 - root - INFO - Signals generated for BTC-GBP.
# 2024-10-05 20:03:35 - root - INFO - Signals generated for ETH-GBP.
# 2024-10-05 20:03:35 - root - INFO - Signals generated for ETH-BTC.
# 2024-10-05 20:03:35 - root - INFO - Applying strategy...
# 2024-10-05 20:03:35 - root - INFO - Strategy completed successfully.
# 2024-10-05 20:03:35 - root - INFO - Strategy signals generated successfully.
# 2024-10-05 20:03:35 - root - INFO - Backtesting completed successfully.
# 2024-10-05 20:03:35 - root - INFO - Trading system completed successfully.

# %%
dic['evaluation_summary']
# Out:
# {'Number of Trading Days': 997,
#  'Number of Trades': 271,
#  'Average Trades Per Month': 8.0,
#  'Start Portfolio Value': '£983',
#  'End Portfolio Value': '£158',
#  'Profit/Loss': '£-825',
#  'Profit Percentage': '-84.0%',
#  'Sharpe Ratio': -1.34,
#  'Fees Paid': '£614.51',
#  'Max Drawdown': '-84.52%',
#  'Average Drawdown Length': '498.0 days',
#  'BTC-GBP Hold Final Value': '£1,302',
#  'BTC-GBP Hold Profit/Loss': '£319',
#  'BTC-GBP Hold Profit Percentage': '32.0%',
#  'ETH-GBP Hold Final Value': '£668',
#  'ETH-GBP Hold Profit/Loss': '£-315',
#  'ETH-GBP Hold Profit Percentage': '-32.0%'}

# %%
plot_prices_positions_and_portfolio(dic)

# %%
portfolio_values_df = pd.DataFrame(dic['backtest_details']['portfolio_value'], columns=['Portfolio Value'])
sns.lineplot(portfolio_values_df)
# Out:
# <Axes: >

# %%
################################################################################
################################PLOTSPLOTSPLOTS#################################
################################################################################

# %%
def plot(df):
    sns.lineplot(data=df, x='Date', y='Close')
    sns.lineplot(data=df, x='Date', y='short_sma')
    sns.lineplot(data=df, x='Date', y='long_sma')

# %%
plot(pd.DataFrame(dic['ETH-BTC']))

# %%
plot(pd.DataFrame(dic['BTC-GBP']))

# %%
plot(pd.DataFrame(dic['ETH-GBP']))

# %%
dic.keys()
# Out:
# dict_keys(['BTC-GBP', 'ETH-GBP', 'ETH-BTC', 'combined_position', 'backtest_details', 'evaluation_summary'])

# %%
dic['backtest_details']['trades']
# Out:
# [{'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.07189041407378326,
#   'price': 13743.1396484375,
#   'transaction_cost': 12.0,
#   'time_point': 0},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.07189041407378326,
#   'price': 14114.2783203125,
#   'time_point': 8},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 14354.65234375,
#   'time_point': 9},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 14750.5732421875,
#   'time_point': 10},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.8782298273619427,
#   'price': 1141.506591796875,
#   'transaction_cost': 12.176175753598653,
#   'time_point': 10},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.8782298273619427,
#   'price': 1160.623779296875,
#   'time_point': 11},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.06520187905928426,
#   'price': 15445.3046875,
#   'transaction_cost': 12.23153305588872,
#   'time_point': 11},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.06520187905928426,
#   'price': 17150.1171875,
#   'time_point': 13},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 17340.36328125,
#   'time_point': 15},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 17227.423828125,
#   'time_point': 16},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 16756.1953125,
#   'time_point': 17},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 17015.861328125,
#   'time_point': 18},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 18299.341796875,
#   'time_point': 19},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 18356.43359375,
#   'time_point': 23},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.8752383469901364,
#   'price': 1262.2861328125,
#   'transaction_cost': 13.418638400543129,
#   'time_point': 23},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.8752383469901364,
#   'price': 1298.6700439453125,
#   'time_point': 24},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1291.2857666015625,
#   'time_point': 25},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1270.0384521484375,
#   'time_point': 27},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1269.111328125,
#   'time_point': 29},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1288.980712890625,
#   'time_point': 30},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1354.7833251953125,
#   'time_point': 35},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1343.940185546875,
#   'time_point': 36},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1387.100830078125,
#   'time_point': 37},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1367.532958984375,
#   'time_point': 38},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1276.397705078125,
#   'time_point': 39},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1255.6932373046875,
#   'time_point': 40},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1276.4637451171875,
#   'time_point': 41},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1257.1356201171875,
#   'time_point': 42},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1407.1600341796875,
#   'time_point': 47},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1404.6990966796875,
#   'time_point': 48},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1397.8165283203125,
#   'time_point': 49},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.05552803178240588,
#   'price': 20224.12890625,
#   'transaction_cost': 13.639749870579639,
#   'time_point': 49},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.05552803178240588,
#   'price': 20624.455078125,
#   'time_point': 50},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20180.0546875,
#   'time_point': 51},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20078.673828125,
#   'time_point': 52},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 19928.169921875,
#   'time_point': 53},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 19425.671875,
#   'time_point': 54},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 19399.294921875,
#   'time_point': 55},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 19716.2109375,
#   'time_point': 56},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.8240730034767517,
#   'price': 1373.0489501953125,
#   'transaction_cost': 13.742824764875127,
#   'time_point': 56},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.8240730034767517,
#   'price': 1354.895751953125,
#   'time_point': 57},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.05656803134565992,
#   'price': 19501.025390625,
#   'transaction_cost': 13.398396140518846,
#   'time_point': 57},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.05656803134565992,
#   'price': 19645.703125,
#   'time_point': 60},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.7964609229164833,
#   'price': 1378.5772705078125,
#   'transaction_cost': 13.335825002190349,
#   'time_point': 60},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.7964609229164833,
#   'price': 1301.9727783203125,
#   'time_point': 62},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1300.70556640625,
#   'time_point': 63},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1303.42529296875,
#   'time_point': 64},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1320.6519775390625,
#   'time_point': 65},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.05453280655104642,
#   'price': 18787.34765625,
#   'transaction_cost': 12.44364528759761,
#   'time_point': 65},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.05453280655104642,
#   'price': 18328.77734375,
#   'time_point': 66},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.7627564226797561,
#   'price': 1294.679931640625,
#   'transaction_cost': 11.994236030447055,
#   'time_point': 66},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.7627564226797561,
#   'price': 1187.698974609375,
#   'time_point': 69},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.053351430499203975,
#   'price': 16776.568359375,
#   'transaction_cost': 10.871100253121536,
#   'time_point': 69},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.053351430499203975,
#   'price': 17145.099609375,
#   'time_point': 70},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.7335405035040009,
#   'price': 1232.0233154296875,
#   'transaction_cost': 10.976587082537995,
#   'time_point': 70},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.7335405035040009,
#   'price': 1316.921630859375,
#   'time_point': 71},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.052000920698205035,
#   'price': 18353.966796875,
#   'transaction_cost': 11.592184274110751,
#   'time_point': 71},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.052000920698205035,
#   'price': 19887.2265625,
#   'time_point': 72},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.7398606036406494,
#   'price': 1380.99560546875,
#   'transaction_cost': 12.40984909660559,
#   'time_point': 72},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.7398606036406494,
#   'price': 1401.9505615234375,
#   'time_point': 73},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.05032044451932931,
#   'price': 20365.5,
#   'transaction_cost': 12.446975864676935,
#   'time_point': 73},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.05032044451932931,
#   'price': 20199.994140625,
#   'time_point': 74},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20687.966796875,
#   'time_point': 75},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23006.376953125,
#   'time_point': 78},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.6854620345809971,
#   'price': 1465.106689453125,
#   'transaction_cost': 12.197672213329168,
#   'time_point': 78},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.6854620345809971,
#   'price': 1478.0440673828125,
#   'time_point': 80},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.04342746285951577,
#   'price': 23049.59375,
#   'transaction_cost': 12.15771712354314,
#   'time_point': 80},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.04342746285951577,
#   'price': 23071.19140625,
#   'time_point': 82},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.6692927449428896,
#   'price': 1479.0242919921875,
#   'transaction_cost': 12.023079695036415,
#   'time_point': 82},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.6692927449428896,
#   'price': 1432.930908203125,
#   'time_point': 83},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.042139720556934615,
#   'price': 22485.712890625,
#   'transaction_cost': 11.508603130377328,
#   'time_point': 83},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.042139720556934615,
#   'price': 22861.2890625,
#   'time_point': 85},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22070.970703125,
#   'time_point': 86},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23068.853515625,
#   'time_point': 90},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.64489129699117,
#   'price': 1475.919921875,
#   'transaction_cost': 11.56041999198067,
#   'time_point': 90},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.64489129699117,
#   'price': 1457.5191650390625,
#   'time_point': 93},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1496.918212890625,
#   'time_point': 94},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1502.001220703125,
#   'time_point': 97},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.04130549686035592,
#   'price': 22482.7734375,
#   'transaction_cost': 11.279297096778338,
#   'time_point': 97},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.04130549686035592,
#   'price': 22500.43359375,
#   'time_point': 98},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22792.720703125,
#   'time_point': 99},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23930.103515625,
#   'time_point': 100},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5953489845831412,
#   'price': 1542.35400390625,
#   'transaction_cost': 11.152699069959452,
#   'time_point': 100},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5953489845831412,
#   'price': 1693.83056640625,
#   'time_point': 108},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.04072363922465697,
#   'price': 24465.37890625,
#   'transaction_cost': 12.101043693190176,
#   'time_point': 108},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.04072363922465697,
#   'price': 23191.21875,
#   'time_point': 109},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22705.197265625,
#   'time_point': 110},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21935.599609375,
#   'time_point': 111},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22370.333984375,
#   'time_point': 112},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22020.271484375,
#   'time_point': 114},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22802.392578125,
#   'time_point': 115},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22790.658203125,
#   'time_point': 116},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23584.421875,
#   'time_point': 117},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23343.34765625,
#   'time_point': 118},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23306.751953125,
#   'time_point': 120},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22500.6171875,
#   'time_point': 121},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22987.365234375,
#   'time_point': 122},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23077.94140625,
#   'time_point': 123},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23367.6640625,
#   'time_point': 125},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22869.396484375,
#   'time_point': 126},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22529.65625,
#   'time_point': 127},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21957.5703125,
#   'time_point': 128},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21909.51171875,
#   'time_point': 129},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21876.76171875,
#   'time_point': 130},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.6394565740661557,
#   'price': 1459.2041015625,
#   'transaction_cost': 11.333169906661203,
#   'time_point': 130},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.6394565740661557,
#   'price': 1451.1427001953125,
#   'time_point': 135},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.042228156667428546,
#   'price': 21710.80859375,
#   'transaction_cost': 11.13531287457606,
#   'time_point': 135},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.042228156667428546,
#   'price': 21656.51953125,
#   'time_point': 136},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.6183839624591462,
#   'price': 1461.1322021484375,
#   'transaction_cost': 10.974178795642214,
#   'time_point': 136},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.6183839624591462,
#   'price': 1459.5645751953125,
#   'time_point': 137},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.04062547980374999,
#   'price': 21950.275390625,
#   'transaction_cost': 10.830855905691333,
#   'time_point': 137},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.04062547980374999,
#   'price': 21618.30859375,
#   'time_point': 138},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21604.578125,
#   'time_point': 139},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21796.966796875,
#   'time_point': 140},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5932514426698944,
#   'price': 1462.64306640625,
#   'transaction_cost': 10.539049909999505,
#   'time_point': 140},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5932514426698944,
#   'price': 1466.2591552734375,
#   'time_point': 145},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.03998034545311092,
#   'price': 21496.11328125,
#   'transaction_cost': 10.43832431032689,
#   'time_point': 145},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.03998034545311092,
#   'price': 22317.84375,
#   'time_point': 150},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.575614730239138,
#   'price': 1531.5240478515625,
#   'transaction_cost': 10.70730123472263,
#   'time_point': 150},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.575614730239138,
#   'price': 1519.9498291015625,
#   'time_point': 154},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.03974972333560222,
#   'price': 21746.23046875,
#   'transaction_cost': 10.498866130263838,
#   'time_point': 154},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.03974972333560222,
#   'price': 20720.51953125,
#   'time_point': 156},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5583692217318438,
#   'price': 1457.371337890625,
#   'transaction_cost': 9.883619024845556,
#   'time_point': 156},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5583692217318438,
#   'price': 1516.176025390625,
#   'time_point': 157},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.038166793541147374,
#   'price': 21915.044921875,
#   'transaction_cost': 10.159032327670122,
#   'time_point': 157},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.038166793541147374,
#   'price': 21169.5625,
#   'time_point': 158},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21108.2265625,
#   'time_point': 159},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21074.724609375,
#   'time_point': 160},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20564.998046875,
#   'time_point': 161},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20620.56640625,
#   'time_point': 162},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20697.91015625,
#   'time_point': 163},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20559.435546875,
#   'time_point': 164},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 19828.720703125,
#   'time_point': 165},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20004.83203125,
#   'time_point': 166},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20529.83984375,
#   'time_point': 167},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20672.70703125,
#   'time_point': 168},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23512.724609375,
#   'time_point': 172},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5391065686318206,
#   'price': 1480.74365234375,
#   'transaction_cost': 9.695691855526988,
#   'time_point': 172},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5391065686318206,
#   'price': 1469.3387451171875,
#   'time_point': 173},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1488.567626953125,
#   'time_point': 174},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1475.586669921875,
#   'time_point': 175},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1493.03955078125,
#   'time_point': 176},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.03268381751108785,
#   'price': 23945.32421875,
#   'transaction_cost': 9.505562028454946,
#   'time_point': 176},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.03268381751108785,
#   'price': 23798.671875,
#   'time_point': 179},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 24074.361328125,
#   'time_point': 182},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5073824798613693,
#   'price': 1514.6314697265625,
#   'transaction_cost': 9.333977382825108,
#   'time_point': 182},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5073824798613693,
#   'price': 1522.749755859375,
#   'time_point': 185},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.03154317269097664,
#   'price': 24200.01171875,
#   'transaction_cost': 9.271398568034693,
#   'time_point': 185},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.03154317269097664,
#   'price': 23471.353515625,
#   'time_point': 187},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23633.802734375,
#   'time_point': 188},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23595.072265625,
#   'time_point': 189},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23501.8828125,
#   'time_point': 190},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5040524365478896,
#   'price': 1451.1915283203125,
#   'transaction_cost': 8.884331486811853,
#   'time_point': 190},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5040524365478896,
#   'price': 1469.6236572265625,
#   'time_point': 197},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1462.4188232421875,
#   'time_point': 198},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1455.9140625,
#   'time_point': 199},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1460.13330078125,
#   'time_point': 200},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.0316524057248322,
#   'price': 23122.35546875,
#   'transaction_cost': 8.889208622801632,
#   'time_point': 200},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.0316524057248322,
#   'price': 23157.908203125,
#   'time_point': 203},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23409.021484375,
#   'time_point': 204},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22772.640625,
#   'time_point': 205},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22668.880859375,
#   'time_point': 206},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22708.185546875,
#   'time_point': 207},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22832.126953125,
#   'time_point': 208},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.4980375568870161,
#   'price': 1454.1221923828125,
#   'transaction_cost': 8.796042074204788,
#   'time_point': 208},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.4980375568870161,
#   'price': 1464.32177734375,
#   'time_point': 210},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.03152922299530737,
#   'price': 22852.951171875,
#   'transaction_cost': 8.751446885816813,
#   'time_point': 210},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.03152922299530737,
#   'price': 22779.40625,
#   'time_point': 212},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23193.3359375,
#   'time_point': 213},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22920.349609375,
#   'time_point': 214},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22806.79296875,
#   'time_point': 216},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22781.71875,
#   'time_point': 217},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22780.19921875,
#   'time_point': 218},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23158.755859375,
#   'time_point': 223},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.4876574061132961,
#   'price': 1455.1165771484375,
#   'transaction_cost': 8.61860375228338,
#   'time_point': 223},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.4876574061132961,
#   'price': 1456.50732421875,
#   'time_point': 224},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.03028305539812177,
#   'price': 23173.1328125,
#   'transaction_cost': 8.5233190045624,
#   'time_point': 224},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.03028305539812177,
#   'price': 23182.29296875,
#   'time_point': 226},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22967.97265625,
#   'time_point': 227},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22550.701171875,
#   'time_point': 228},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20917.2734375,
#   'time_point': 229},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20554.685546875,
#   'time_point': 232},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20473.802734375,
#   'time_point': 233},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20447.29296875,
#   'time_point': 234},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20778.916015625,
#   'time_point': 235},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20776.298828125,
#   'time_point': 236},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20672.80078125,
#   'time_point': 238},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20724.138671875,
#   'time_point': 239},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20701.2890625,
#   'time_point': 240},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21943.6796875,
#   'time_point': 241},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21474.376953125,
#   'time_point': 242},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20465.091796875,
#   'time_point': 243},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20497.927734375,
#   'time_point': 244},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20550.353515625,
#   'time_point': 245},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20631.08203125,
#   'time_point': 246},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20449.73046875,
#   'time_point': 247},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20509.291015625,
#   'time_point': 248},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21033.537109375,
#   'time_point': 250},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20782.70703125,
#   'time_point': 251},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20774.705078125,
#   'time_point': 252},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20684.638671875,
#   'time_point': 253},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20117.19140625,
#   'time_point': 254},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 20681.140625,
#   'time_point': 255},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21000.1015625,
#   'time_point': 256},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21401.142578125,
#   'time_point': 257},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21403.005859375,
#   'time_point': 260},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21605.47265625,
#   'time_point': 261},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21957.3046875,
#   'time_point': 262},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22010.08203125,
#   'time_point': 263},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21612.185546875,
#   'time_point': 264},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21713.56640625,
#   'time_point': 265},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21716.95703125,
#   'time_point': 266},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21449.62109375,
#   'time_point': 267},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21534.431640625,
#   'time_point': 268},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21715.8515625,
#   'time_point': 270},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5268938021840958,
#   'price': 1316.40625,
#   'transaction_cost': 8.42436794673774,
#   'time_point': 270},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5268938021840958,
#   'price': 1354.339111328125,
#   'time_point': 271},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.03184284836743214,
#   'price': 22140.9140625,
#   'transaction_cost': 8.563114605771663,
#   'time_point': 271},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.03184284836743214,
#   'price': 22950.62109375,
#   'time_point': 274},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22771.09765625,
#   'time_point': 275},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22712.21484375,
#   'time_point': 276},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22904.25390625,
#   'time_point': 277},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22495.71484375,
#   'time_point': 278},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22835.91796875,
#   'time_point': 279},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22850.345703125,
#   'time_point': 280},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22860.568359375,
#   'time_point': 281},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22518.349609375,
#   'time_point': 282},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22288.51171875,
#   'time_point': 283},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21821.1640625,
#   'time_point': 284},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 21961.98046875,
#   'time_point': 285},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22154.529296875,
#   'time_point': 286},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22155.8046875,
#   'time_point': 287},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 22344.654296875,
#   'time_point': 288},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23354.25,
#   'time_point': 289},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23333.166015625,
#   'time_point': 290},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23331.81640625,
#   'time_point': 291},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 23666.240234375,
#   'time_point': 292},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 24622.1953125,
#   'time_point': 294},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 27011.0703125,
#   'time_point': 296},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 27874.478515625,
#   'time_point': 297},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 28509.30078125,
#   'time_point': 298},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 27959.91796875,
#   'time_point': 300},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 28108.150390625,
#   'time_point': 301},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 28513.58984375,
#   'time_point': 302},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 28365.15234375,
#   'time_point': 303},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 28349.2578125,
#   'time_point': 308},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.48098680197510674,
#   'price': 1501.1708984375,
#   'transaction_cost': 8.769757769120051,
#   'time_point': 308},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.48098680197510674,
#   'price': 1700.3111572265625,
#   'time_point': 314},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.026468220288391874,
#   'price': 30527.677734375,
#   'transaction_cost': 9.813926710523967,
#   'time_point': 314},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.026468220288391874,
#   'price': 29724.306640625,
#   'time_point': 317},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 28444.43359375,
#   'time_point': 318},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 30495.119140625,
#   'time_point': 319},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 29123.71484375,
#   'time_point': 320},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 29378.42578125,
#   'time_point': 321},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 29369.611328125,
#   'time_point': 322},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 30021.13671875,
#   'time_point': 323},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.4808324494355656,
#   'price': 1616.589111328125,
#   'transaction_cost': 9.440993953005263,
#   'time_point': 323},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.4808324494355656,
#   'price': 1616.7012939453125,
#   'time_point': 324},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02563414877283758,
#   'price': 29961.365234375,
#   'transaction_cost': 9.328349318080475,
#   'time_point': 324},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02563414877283758,
#   'price': 28550.5546875,
#   'time_point': 325},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 29971.88671875,
#   'time_point': 326},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.4374456643865511,
#   'price': 1652.9749755859375,
#   'transaction_cost': 8.782429996876925,
#   'time_point': 326},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.4374456643865511,
#   'price': 1654.1651611328125,
#   'time_point': 329},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02383471181006154,
#   'price': 29995.080078125,
#   'transaction_cost': 8.683288535001953,
#   'time_point': 329},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02383471181006154,
#   'price': 29746.205078125,
#   'time_point': 330},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 29485.482421875,
#   'time_point': 331},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 29757.44140625,
#   'time_point': 332},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 29820.529296875,
#   'time_point': 333},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 29858.728515625,
#   'time_point': 334},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 31086.19140625,
#   'time_point': 336},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 31451.201171875,
#   'time_point': 337},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.4058924293673131,
#   'price': 1725.7880859375,
#   'transaction_cost': 8.507906705761181,
#   'time_point': 337},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.4058924293673131,
#   'price': 1775.5838623046875,
#   'time_point': 338},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1821.303466796875,
#   'time_point': 339},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.020344276616943283,
#   'price': 34999.90234375,
#   'transaction_cost': 8.648352568994957,
#   'time_point': 339},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.020344276616943283,
#   'price': 34838.3125,
#   'time_point': 340},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 34846.98828125,
#   'time_point': 343},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.3753157137699115,
#   'price': 1865.7762451171875,
#   'transaction_cost': 8.505123196410153,
#   'time_point': 343},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.3753157137699115,
#   'price': 1873.8612060546875,
#   'time_point': 344},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.019925246375999798,
#   'price': 34872.84765625,
#   'transaction_cost': 8.439474672673947,
#   'time_point': 344},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.019925246375999798,
#   'price': 32854.87890625,
#   'time_point': 345},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.36498236179667665,
#   'price': 1772.1016845703125,
#   'transaction_cost': 7.85569868232804,
#   'time_point': 345},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.36498236179667665,
#   'price': 1751.9942626953125,
#   'time_point': 346},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1791.1866455078125,
#   'time_point': 347},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1813.99951171875,
#   'time_point': 348},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.018752576404772736,
#   'price': 33689.96484375,
#   'transaction_cost': 7.673364046233148,
#   'time_point': 348},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.018752576404772736,
#   'price': 33288.76171875,
#   'time_point': 350},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 32643.669921875,
#   'time_point': 351},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 33687.30078125,
#   'time_point': 352},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 33204.51171875,
#   'time_point': 353},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 34537.046875,
#   'time_point': 354},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 33936.44921875,
#   'time_point': 358},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 34329.69140625,
#   'time_point': 359},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 33411.42578125,
#   'time_point': 360},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 33939.73046875,
#   'time_point': 361},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 33474.33203125,
#   'time_point': 362},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.33456404004396173,
#   'price': 1843.4708251953125,
#   'transaction_cost': 7.491000570613599,
#   'time_point': 362},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.33456404004396173,
#   'price': 1799.1085205078125,
#   'time_point': 364},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1792.20068359375,
#   'time_point': 365},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1848.2005615234375,
#   'time_point': 366},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1744.4437255859375,
#   'time_point': 368},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1789.2750244140625,
#   'time_point': 369},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1782.8277587890625,
#   'time_point': 370},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1761.592041015625,
#   'time_point': 371},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1747.9061279296875,
#   'time_point': 372},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1831.0294189453125,
#   'time_point': 373},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1844.6239013671875,
#   'time_point': 374},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.01638405980965048,
#   'price': 36297.109375,
#   'transaction_cost': 7.223004181183303,
#   'time_point': 374},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.01638405980965048,
#   'price': 36284.11328125,
#   'time_point': 376},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.28652610148364804,
#   'price': 2049.89111328125,
#   'transaction_cost': 7.133772985681601,
#   'time_point': 376},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.28652610148364804,
#   'price': 1941.18408203125,
#   'time_point': 379},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1974.984130859375,
#   'time_point': 380},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2047.6943359375,
#   'time_point': 381},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.01609179903916806,
#   'price': 34149.4140625,
#   'transaction_cost': 6.674398887438337,
#   'time_point': 381},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.01609179903916806,
#   'price': 33716.08984375,
#   'time_point': 382},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.2687710672624765,
#   'price': 1994.418212890625,
#   'transaction_cost': 6.510630505825923,
#   'time_point': 382},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.2687710672624765,
#   'price': 1940.798828125,
#   'time_point': 383},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.015876729292140308,
#   'price': 32460.779296875,
#   'transaction_cost': 6.25956686852304,
#   'time_point': 383},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.015876729292140308,
#   'price': 32797.23046875,
#   'time_point': 385},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 32714.728515625,
#   'time_point': 386},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 31092.654296875,
#   'time_point': 387},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 31396.26171875,
#   'time_point': 388},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 31511.9609375,
#   'time_point': 389},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 31428.02734375,
#   'time_point': 390},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 32903.35546875,
#   'time_point': 391},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 33141.9140625,
#   'time_point': 392},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 33107.82421875,
#   'time_point': 393},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 33583.87890625,
#   'time_point': 396},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 33794.796875,
#   'time_point': 397},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 34184.9765625,
#   'time_point': 398},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 34185.53125,
#   'time_point': 402},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.2733278984944821,
#   'price': 1882.2235107421875,
#   'transaction_cost': 6.248552996211357,
#   'time_point': 402},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.2733278984944821,
#   'price': 1919.5382080078125,
#   'time_point': 403},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.014768809423231992,
#   'price': 35098.79296875,
#   'transaction_cost': 6.295960133695673,
#   'time_point': 403},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.014768809423231992,
#   'price': 35894.15234375,
#   'time_point': 404},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.2731599684277006,
#   'price': 1917.3839111328125,
#   'transaction_cost': 6.3613667444795965,
#   'time_point': 404},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.2731599684277006,
#   'price': 1969.6845703125,
#   'time_point': 405},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 1980.5426025390625,
#   'time_point': 406},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2105.0390625,
#   'time_point': 408},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.013436230157542688,
#   'price': 39563.3671875,
#   'transaction_cost': 6.456467700469098,
#   'time_point': 408},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.013436230157542688,
#   'price': 41239.640625,
#   'time_point': 410},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.2476685807598275,
#   'price': 2210.43798828125,
#   'transaction_cost': 6.649263636622171,
#   'time_point': 410},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.2476685807598275,
#   'price': 2241.782958984375,
#   'time_point': 411},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.013306410704427297,
#   'price': 41224.984375,
#   'transaction_cost': 6.662630445878721,
#   'time_point': 411},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.013306410704427297,
#   'price': 41390.42578125,
#   'time_point': 412},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.244583367410991,
#   'price': 2224.79931640625,
#   'transaction_cost': 6.609096056117142,
#   'time_point': 412},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.244583367410991,
#   'price': 2211.29443359375,
#   'time_point': 413},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.01303437572495142,
#   'price': 40995.87890625,
#   'transaction_cost': 6.490150066866473,
#   'time_point': 413},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.01303437572495142,
#   'price': 41134.4921875,
#   'time_point': 415},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.22653064635701994,
#   'price': 2338.440673828125,
#   'transaction_cost': 6.433949117123446,
#   'time_point': 415},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.22653064635701994,
#   'price': 2350.302734375,
#   'time_point': 417},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.012824316462569523,
#   'price': 41017.90625,
#   'transaction_cost': 6.3889871706316805,
#   'time_point': 417},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.012824316462569523,
#   'price': 40519.796875,
#   'time_point': 418},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 40009.44921875,
#   'time_point': 419},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 40674.4375,
#   'time_point': 420},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 40830.35546875,
#   'time_point': 421},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.20898159514251505,
#   'price': 2456.690185546875,
#   'transaction_cost': 6.235664377488427,
#   'time_point': 421},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.20898159514251505,
#   'price': 2674.066162109375,
#   'time_point': 424},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.011184090469993656,
#   'price': 49366.96875,
#   'transaction_cost': 6.705967344890885,
#   'time_point': 424},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.011184090469993656,
#   'price': 48467.28515625,
#   'time_point': 425},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 49332.90625,
#   'time_point': 426},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.1973346467285602,
#   'price': 2713.95703125,
#   'transaction_cost': 6.504750024269766,
#   'time_point': 426},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.1973346467285602,
#   'price': 2703.682861328125,
#   'time_point': 427},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.010755878944248488,
#   'price': 49008.35546875,
#   'transaction_cost': 6.402363627674981,
#   'time_point': 427},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.010755878944248488,
#   'price': 53847.51171875,
#   'time_point': 429},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 50218.5625,
#   'time_point': 430},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 52232.12890625,
#   'time_point': 432},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.1892446868814308,
#   'price': 3023.742431640625,
#   'transaction_cost': 6.950127809950523,
#   'time_point': 432},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.1892446868814308,
#   'price': 3019.067626953125,
#   'time_point': 435},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.010514104133756906,
#   'price': 53688.4921875,
#   'transaction_cost': 6.856110092839302,
#   'time_point': 435},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.010514104133756906,
#   'price': 54507.015625,
#   'time_point': 440},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 51303.98046875,
#   'time_point': 441},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 53719.3984375,
#   'time_point': 442},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 53077.1171875,
#   'time_point': 443},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 48683.68359375,
#   'time_point': 444},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 53370.8203125,
#   'time_point': 449},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 55363.09765625,
#   'time_point': 450},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 55423.37109375,
#   'time_point': 451},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 55050.09375,
#   'time_point': 452},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 56052.28515625,
#   'time_point': 453},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 55358.6171875,
#   'time_point': 454},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 55160.1953125,
#   'time_point': 455},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 56444.890625,
#   'time_point': 456},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 55557.0703125,
#   'time_point': 457},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 52040.75,
#   'time_point': 458},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 52153.47265625,
#   'time_point': 459},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 54203.6484375,
#   'time_point': 460},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 53677.484375,
#   'time_point': 461},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 54515.01171875,
#   'time_point': 462},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 56591.99609375,
#   'time_point': 464},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.19394603937828458,
#   'price': 2919.44775390625,
#   'transaction_cost': 6.877109259618778,
#   'time_point': 464},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.19394603937828458,
#   'price': 2792.00341796875,
#   'time_point': 467},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2603.38525390625,
#   'time_point': 468},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2412.219970703125,
#   'time_point': 469},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2533.711181640625,
#   'time_point': 470},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2481.7041015625,
#   'time_point': 472},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2473.343994140625,
#   'time_point': 475},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.010365043662789957,
#   'price': 51615.80078125,
#   'transaction_cost': 6.497976058148068,
#   'time_point': 475},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.010365043662789957,
#   'price': 54121.07421875,
#   'time_point': 478},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.21378405703084027,
#   'price': 2592.50244140625,
#   'transaction_cost': 6.731607568253276,
#   'time_point': 478},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.21378405703084027,
#   'price': 2411.97705078125,
#   'time_point': 486},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.01049281164113433,
#   'price': 48552.71875,
#   'transaction_cost': 6.187706872575561,
#   'time_point': 486},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.01049281164113433,
#   'price': 47147.68359375,
#   'time_point': 488},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 49862.8671875,
#   'time_point': 493},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 48977.3984375,
#   'time_point': 494},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 50339.46484375,
#   'time_point': 495},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 48533.24609375,
#   'time_point': 496},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 48541.76953125,
#   'time_point': 497},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 49073.1171875,
#   'time_point': 498},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 52163.1328125,
#   'time_point': 505},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.20217074622812672,
#   'price': 2417.6357421875,
#   'transaction_cost': 5.936541159180217,
#   'time_point': 505},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.20217074622812672,
#   'price': 2975.54638671875,
#   'time_point': 509},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.011105933624244753,
#   'price': 53516.40234375,
#   'transaction_cost': 7.21882120127203,
#   'time_point': 509},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.011105933624244753,
#   'price': 53533.17578125,
#   'time_point': 514},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.1951409827078828,
#   'price': 3010.138916015625,
#   'transaction_cost': 7.134430763059071,
#   'time_point': 514},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.1951409827078828,
#   'price': 2963.6376953125,
#   'time_point': 515},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.010736343682445377,
#   'price': 53219.91015625,
#   'transaction_cost': 6.939926067040874,
#   'time_point': 515},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.010736343682445377,
#   'price': 52988.45703125,
#   'time_point': 517},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 53157.6640625,
#   'time_point': 518},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.18774675279389075,
#   'price': 2993.7958984375,
#   'transaction_cost': 6.826827430679871,
#   'time_point': 518},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.18774675279389075,
#   'price': 2940.2353515625,
#   'time_point': 520},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.010153971714394883,
#   'price': 53712.51953125,
#   'transaction_cost': 6.624235676467958,
#   'time_point': 520},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.010153971714394883,
#   'price': 54719.22265625,
#   'time_point': 526},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 54623.09765625,
#   'time_point': 527},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 52851.53515625,
#   'time_point': 528},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 52342.5546875,
#   'time_point': 530},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.20180470290158345,
#   'price': 2720.204345703125,
#   'transaction_cost': 6.667409269022858,
#   'time_point': 530},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.20180470290158345,
#   'price': 2761.861083984375,
#   'time_point': 534},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.010529498082211776,
#   'price': 52297.67578125,
#   'transaction_cost': 6.688278666106944,
#   'time_point': 534},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.010529498082211776,
#   'price': 51263.6796875,
#   'time_point': 535},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 51068.2109375,
#   'time_point': 536},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 51208.48046875,
#   'time_point': 537},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 50664.90234375,
#   'time_point': 538},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.19188509646336255,
#   'price': 2779.285400390625,
#   'transaction_cost': 6.4773698034798,
#   'time_point': 538},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.19188509646336255,
#   'price': 2761.93359375,
#   'time_point': 539},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2705.02783203125,
#   'time_point': 540},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2666.58740234375,
#   'time_point': 546},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2714.0146484375,
#   'time_point': 547},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.010566760062435095,
#   'price': 49552.95703125,
#   'transaction_cost': 6.3596867287454435,
#   'time_point': 547},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.010566760062435095,
#   'price': 49704.4140625,
#   'time_point': 548},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 47205.05859375,
#   'time_point': 550},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.200878182401579,
#   'price': 2583.217529296875,
#   'transaction_cost': 6.302575409308347,
#   'time_point': 550},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.200878182401579,
#   'price': 2394.75732421875,
#   'time_point': 551},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2327.009521484375,
#   'time_point': 552},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.010747500498837973,
#   'price': 44222.546875,
#   'transaction_cost': 5.772653982983176,
#   'time_point': 552},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.010747500498837973,
#   'price': 45517.6328125,
#   'time_point': 553},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.20170143877577104,
#   'price': 2396.266357421875,
#   'transaction_cost': 5.870409376299209,
#   'time_point': 553},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.20170143877577104,
#   'price': 2448.22216796875,
#   'time_point': 560},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2605.07958984375,
#   'time_point': 564},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2645.96240234375,
#   'time_point': 565},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2660.45263671875,
#   'time_point': 569},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.00933513871730868,
#   'price': 52263.19921875,
#   'transaction_cost': 5.925719204664412,
#   'time_point': 569},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.00933513871730868,
#   'price': 50275.84375,
#   'time_point': 578},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 51350.015625,
#   'time_point': 579},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 47958.04296875,
#   'time_point': 580},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 47384.11328125,
#   'time_point': 581},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 45447.41796875,
#   'time_point': 582},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 48416.046875,
#   'time_point': 586},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 47816.640625,
#   'time_point': 587},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 47772.55859375,
#   'time_point': 588},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 46058.68359375,
#   'time_point': 589},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 46476.6015625,
#   'time_point': 590},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 47110.05859375,
#   'time_point': 591},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 45795.453125,
#   'time_point': 592},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 44763.27734375,
#   'time_point': 593},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 45471.078125,
#   'time_point': 594},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 45952.796875,
#   'time_point': 595},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 45173.3671875,
#   'time_point': 596},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0,
#   'price': 45801.75,
#   'time_point': 597},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.22838292180431724,
#   'price': 2030.3619384765625,
#   'transaction_cost': 5.631983706431839,
#   'time_point': 597},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.22838292180431724,
#   'price': 1974.15966796875,
#   'time_point': 598},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0,
#   'price': 2009.8809814453125,
#   'time_point': 599},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.009533300787915406,
#   'price': 46726.1015625,
#   'transaction_cost': 5.410372236947327,
#   'time_point': 599},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.009533300787915406,
#   'price': 46104.125,
#   'time_point': 600}]

# %%
dic['combined_position']
# Out:
# {'final_signal': ['BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'ETH',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC',
#   'ETH',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC']}

# %%
dic.keys()
# Out:
# dict_keys(['BTC-GBP', 'ETH-GBP', 'ETH-BTC', 'combined_position', 'backtest_details', 'evaluation_summary'])
