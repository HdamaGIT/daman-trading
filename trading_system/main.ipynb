# %%
from datetime import datetime
import matplotlib as plt
import seaborn as sns
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2
from config import AppConfig
from main import main
from backtesting.evaluate_plot import plot_prices_positions_and_portfolio
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
################################################################################
################################################################################
################################################################################

# %%
# Initialize the app configuration
config = AppConfig(system_mode='development')
# 
# Example usage
print(config.summary())
# Out:
# {'System Mode': 'development', 'Tickers': ['BTC-GBP', 'ETH-GBP', 'ETH-BTC'], 'Start Date': datetime.date(2022, 1, 1), 'End Date': datetime.date(2025, 6, 22), 'Database Path': 'outputs/mydatabase.db', 'File Path': '../outputs/'}

# %%
dic = main()
# Out:
# 2025-06-22 16:16:01 - root - INFO - Starting the trading system...
# 2025-06-22 16:16:01 - root - INFO - Config loaded successfully.
# [*********************100%***********************]  1 of 1 completed
# 2025-06-22 16:16:01 - yfinance - ERROR -
# 1 Failed download:
# 2025-06-22 16:16:01 - yfinance - ERROR - ['BTC-GBP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2022-01-01 -> 2025-06-22)')
# 2025-06-22 16:16:01 - root - ERROR - No data fetched for BTC-GBP. Data may not be available for this ticker.
# 2025-06-22 16:16:01 - root - ERROR - Error fetching data for BTC-GBP. Skipping this ticker.
# [*********************100%***********************]  1 of 1 completed
# 2025-06-22 16:16:01 - yfinance - ERROR -
# 1 Failed download:
# 2025-06-22 16:16:01 - yfinance - ERROR - ['ETH-GBP']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2022-01-01 -> 2025-06-22)')
# 2025-06-22 16:16:01 - root - ERROR - No data fetched for ETH-GBP. Data may not be available for this ticker.
# 2025-06-22 16:16:01 - root - ERROR - Error fetching data for ETH-GBP. Skipping this ticker.
# [*********************100%***********************]  1 of 1 completed
# 2025-06-22 16:16:02 - yfinance - ERROR -
# 1 Failed download:
# 2025-06-22 16:16:02 - yfinance - ERROR - ['ETH-BTC']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2022-01-01 -> 2025-06-22)')
# 2025-06-22 16:16:02 - root - ERROR - No data fetched for ETH-BTC. Data may not be available for this ticker.
# 2025-06-22 16:16:02 - root - ERROR - Error fetching data for ETH-BTC. Skipping this ticker.
# 2025-06-22 16:16:02 - root - INFO - Data loaded successfully.
# 2025-06-22 16:16:02 - root - INFO - Calculating indicators...
# 2025-06-22 16:16:02 - root - INFO - Generating all signals...
# 2025-06-22 16:16:02 - root - INFO - Applying strategy...
# 2025-06-22 16:16:02 - root - ERROR - Error in strategy execution:
# 2025-06-22 16:16:02 - root - ERROR - Error generating strategy signals:
# 2025-06-22 16:16:02 - root - ERROR - Terminating due to strategy signal generation failure.

# %%
dic['evaluation_summary']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dic['evaluation_summary']
#
# TypeError: 'NoneType' object is not subscriptable

# %%
plot_prices_positions_and_portfolio(dic)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_prices_positions_and_portfolio(dic)
#
# File ~/PycharmProjects/daman-trading/trading_system/backtesting/evaluate_plot.py:13, in plot_prices_positions_and_portfolio(dic)
#      12 def plot_prices_positions_and_portfolio(dic):
# ---> 13     btc_gbp_df = pd.DataFrame(dic['BTC-GBP'])
#      14     eth_gbp_df = pd.DataFrame(dic['ETH-GBP'])
#      15     positions_df = pd.DataFrame(dic['combined_position'])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
portfolio_values_df = pd.DataFrame(dic['backtest_details']['portfolio_value'], columns=['Portfolio Value'])
sns.lineplot(portfolio_values_df)
# Out:
# <Axes: >

# %%
################################################################################
################################PLOTSPLOTSPLOTS#################################
################################################################################

# %%
def plot(df):
    sns.lineplot(data=df, x='Date', y='Close')
    sns.lineplot(data=df, x='Date', y='short_sma')
    sns.lineplot(data=df, x='Date', y='long_sma')

# %%
plot(pd.DataFrame(dic['ETH-BTC']))

# %%
plot(pd.DataFrame(dic['BTC-GBP']))

# %%
plot(pd.DataFrame(dic['ETH-GBP']))

# %%
dic.keys()
# Out:
# dict_keys(['BTC-GBP', 'ETH-GBP', 'ETH-BTC', 'combined_position', 'backtest_details', 'evaluation_summary'])

# %%
dic['backtest_details']['trades']
# Out:
# [{'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02955737649895739,
#   'price': 33426.511992187494,
#   'transaction_cost': 12.0,
#   'time_point': 59},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02955737649895739,
#   'price': 29440.128017578125,
#   'time_point': 62},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02686586394494392,
#   'price': 32000.864531249998,
#   'transaction_cost': 10.442075375916728,
#   'time_point': 67},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02686586394494392,
#   'price': 29948.5283203125,
#   'time_point': 68},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.025262691288589805,
#   'price': 31466.875839843746,
#   'transaction_cost': 9.655117046457786,
#   'time_point': 74},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.025262691288589805,
#   'price': 31187.581220703123,
#   'time_point': 78},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.3288120671609469,
#   'price': 2367.393801269531,
#   'transaction_cost': 9.454586836997326,
#   'time_point': 82},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.3288120671609469,
#   'price': 2299.5601440429687,
#   'time_point': 103},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.3403496303069779,
#   'price': 2194.947725830078,
#   'transaction_cost': 9.07347749428432,
#   'time_point': 125},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.3403496303069779,
#   'price': 2032.2432885742187,
#   'time_point': 127},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.3570950912284165,
#   'price': 1913.700831298828,
#   'transaction_cost': 8.300079023520867,
#   'time_point': 129},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.3570950912284165,
#   'price': 1685.3100360107421,
#   'time_point': 130},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5255096396249397,
#   'price': 1131.4619274902343,
#   'transaction_cost': 7.221791292689062,
#   'time_point': 197},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5255096396249397,
#   'price': 1338.0199340820313,
#   'time_point': 213},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.03602281930109417,
#   'price': 19285.127548828124,
#   'transaction_cost': 8.437708480445206,
#   'time_point': 220},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.03602281930109417,
#   'price': 19513.862265625,
#   'time_point': 221},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.45569448528060325,
#   'price': 1524.067164916992,
#   'transaction_cost': 8.435332011132594,
#   'time_point': 221},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.45569448528060325,
#   'price': 1514.1018969726563,
#   'time_point': 228},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.48508930450331955,
#   'price': 1405.2840655517577,
#   'transaction_cost': 8.279614615240074,
#   'time_point': 247},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.48508930450331955,
#   'price': 1458.747734375,
#   'time_point': 254},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5168587362459908,
#   'price': 1352.6547967529295,
#   'transaction_cost': 8.491475086965142,
#   'time_point': 298},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5168587362459908,
#   'price': 1147.9963110351562,
#   'time_point': 311},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5726513449952866,
#   'price': 1023.7148739624022,
#   'transaction_cost': 7.120223070440282,
#   'time_point': 332},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5726513449952866,
#   'price': 1004.3292181396484,
#   'time_point': 340},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5399052839291578,
#   'price': 1052.4603643798828,
#   'transaction_cost': 6.901565731028811,
#   'time_point': 341},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5399052839291578,
#   'price': 1027.984638671875,
#   'time_point': 343},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.5235268382583139,
#   'price': 1047.4232189941406,
#   'transaction_cost': 6.6601720586034165,
#   'time_point': 368},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.5235268382583139,
#   'price': 1180.8988427734375,
#   'time_point': 377},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.0327594096320398,
#   'price': 18645.435234375,
#   'transaction_cost': 7.418786849520955,
#   'time_point': 390},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.0327594096320398,
#   'price': 18401.873974609374,
#   'time_point': 394},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.029738672888254013,
#   'price': 20027.81077148437,
#   'transaction_cost': 7.23401433037681,
#   'time_point': 418},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.029738672888254013,
#   'price': 19328.543515625,
#   'time_point': 419},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.45866190383510885,
#   'price': 1238.1834320068358,
#   'transaction_cost': 6.8976627962106605,
#   'time_point': 435},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.45866190383510885,
#   'price': 1374.0906274414062,
#   'time_point': 437},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02807226760887364,
#   'price': 22181.325556640622,
#   'transaction_cost': 7.562916278691056,
#   'time_point': 451},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02807226760887364,
#   'price': 22519.28697265625,
#   'time_point': 454},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.36350251861692473,
#   'price': 1718.2313983154295,
#   'transaction_cost': 7.586009403089139,
#   'time_point': 471},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.36350251861692473,
#   'price': 1466.8349029541016,
#   'time_point': 479},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.3636187337214909,
#   'price': 1448.7696990966795,
#   'transaction_cost': 6.39837817942834,
#   'time_point': 498},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.3636187337214909,
#   'price': 1452.2667523193359,
#   'time_point': 502},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.35762585256117996,
#   'price': 1458.8837384033202,
#   'transaction_cost': 6.336856770050148,
#   'time_point': 503},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.35762585256117996,
#   'price': 1457.2424810791015,
#   'time_point': 525},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.0218325619896762,
#   'price': 23583.75594726562,
#   'transaction_cost': 6.253771016211394,
#   'time_point': 538},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.0218325619896762,
#   'price': 23956.8404296875,
#   'time_point': 543},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.022014141074298037,
#   'price': 23474.12654296875,
#   'transaction_cost': 6.2764704450952005,
#   'time_point': 585},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.022014141074298037,
#   'price': 22853.13279296875,
#   'time_point': 592},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.37401960327145956,
#   'price': 1328.9543646240234,
#   'transaction_cost': 6.03710507152897,
#   'time_point': 597},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.37401960327145956,
#   'price': 1276.96978515625,
#   'time_point': 599},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.35661646983750306,
#   'price': 1323.2153631591796,
#   'transaction_cost': 5.731340789205379,
#   'time_point': 604},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.35661646983750306,
#   'price': 1303.7908166503905,
#   'time_point': 605},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02105082088136369,
#   'price': 21822.134238281247,
#   'transaction_cost': 5.57943934128501,
#   'time_point': 630},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02105082088136369,
#   'price': 22835.86798828125,
#   'time_point': 639},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.02100765827286284,
#   'price': 22608.19341796875,
#   'transaction_cost': 5.768565200301308,
#   'time_point': 643},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.02100765827286284,
#   'price': 22721.73837890625,
#   'time_point': 644},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.020536068635669945,
#   'price': 22964.59743164062,
#   'transaction_cost': 5.72796618275346,
#   'time_point': 645},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.020536068635669945,
#   'price': 22177.06916015625,
#   'time_point': 648},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.01918839587416856,
#   'price': 23449.831845703124,
#   'transaction_cost': 5.465157772931616,
#   'time_point': 655},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.01918839587416856,
#   'price': 26876.0149609375,
#   'time_point': 661},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.013752914104375005,
#   'price': 37048.084453125,
#   'transaction_cost': 6.188491375086548,
#   'time_point': 738},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.013752914104375005,
#   'price': 36403.55583984375,
#   'time_point': 740},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.24850477537729593,
#   'price': 1990.49340637207,
#   'transaction_cost': 6.007859718710282,
#   'time_point': 742},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.24850477537729593,
#   'price': 1756.7185333251953,
#   'time_point': 753},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.012683426749912553,
#   'price': 34006.13396484375,
#   'transaction_cost': 5.238635334301325,
#   'time_point': 760},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.012683426749912553,
#   'price': 34014.60359375,
#   'time_point': 767},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.1776866809154492,
#   'price': 2398.855502929687,
#   'transaction_cost': 5.177060797303685,
#   'time_point': 781},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.1776866809154492,
#   'price': 2660.695831298828,
#   'time_point': 789},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.15370790126688122,
#   'price': 3038.861143798828,
#   'transaction_cost': 5.673242534268729,
#   'time_point': 797},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.15370790126688122,
#   'price': 3095.236574707031,
#   'time_point': 802},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.00858081462836862,
#   'price': 54779.550703124994,
#   'transaction_cost': 5.709147813872496,
#   'time_point': 805},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.00858081462836862,
#   'price': 51047.46056640625,
#   'time_point': 806},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.008159378996422969,
#   'price': 53039.876074218744,
#   'transaction_cost': 5.2563455564314685,
#   'time_point': 868},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.008159378996422969,
#   'price': 54906.17939453125,
#   'time_point': 872},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.1499098971477248,
#   'price': 2952.602406005859,
#   'transaction_cost': 5.376003923106839,
#   'time_point': 873},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.1499098971477248,
#   'price': 2969.9326489257815,
#   'time_point': 886},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.007877704575414441,
#   'price': 55838.55374999999,
#   'transaction_cost': 5.342667575233604,
#   'time_point': 887},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.007877704575414441,
#   'price': 54445.62654296875,
#   'time_point': 891},
#  {'asset': 'ETH',
#   'action': 'buy',
#   'qty': 0.15171217227504388,
#   'price': 2793.181827392578,
#   'transaction_cost': 5.14687873594621,
#   'time_point': 903},
#  {'asset': 'ETH',
#   'action': 'sell',
#   'qty': 0.15171217227504388,
#   'price': 2707.0772607421873,
#   'time_point': 913},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.007966004413219154,
#   'price': 50937.48281249999,
#   'transaction_cost': 4.928358860922871,
#   'time_point': 936},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.007966004413219154,
#   'price': 50024.46453125,
#   'time_point': 943},
#  {'asset': 'BTC',
#   'action': 'buy',
#   'qty': 0.008229364403651122,
#   'price': 47842.475390625,
#   'transaction_cost': 4.781941262698351,
#   'time_point': 995},
#  {'asset': 'BTC',
#   'action': 'sell',
#   'qty': 0.008229364403651122,
#   'price': 45602.222011718746,
#   'time_point': 1005}]

# %%
dic['combined_position']
# Out:
# {'final_signal': ['BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'GBP',
#   'ETH',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'ETH',
#   'BTC',
#   'BTC',
#   'GBP',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC',
#   'ETH',
#   'GBP',
#   'BTC',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'GBP',
#   'GBP',
#   'ETH',
#   'ETH',
#   'ETH',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'BTC',
#   'BTC',
#   'BTC',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'GBP',
#   'ETH',
#   'GBP',
#   'BTC',
#   'GBP',
#   'BTC']}

# %%
dic.keys()
# Out:
# dict_keys(['BTC-GBP', 'ETH-GBP', 'ETH-BTC', 'combined_position', 'backtest_details', 'evaluation_summary'])
