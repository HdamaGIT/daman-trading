# %%
from datetime import datetime
import matplotlib as plt
import seaborn as sns
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2
# from config import AppConfig
from main import main
from backtesting.evaluate_plot import plot_prices_positions_and_portfolio
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
################################################################################
################################################################################
################################################################################

# %%
# # Initialize the app configuration
# config = AppConfig(system_mode='development')
# # 
# # Example usage
# print(config.summary())

# %%
dic = main()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
dic['evaluation_summary']
# Out:
# {'Number of Trading Days': 1552,
#  'Number of Trades': 1152,
#  'Average Trades Per Month': 22.0,
#  'Start Portfolio Value': '£4,997',
#  'End Portfolio Value': '£180,045',
#  'Profit/Loss': '£175,048',
#  'Profit Percentage': '3503.0%',
#  'Sharpe Ratio': 2.0,
#  'Fees Paid': '£684,874',
#  'Average Hold Duration': 'TBD',
#  'Max Hold Duration': 'TBD',
#  'Max Drawdown': '-46.94%',
#  'Average Drawdown Length': '24.33 days',
#  'BTC-GBP Hold Final Value': '£48,712',
#  'BTC-GBP Hold Profit/Loss': '£43,716',
#  'BTC-GBP Hold Profit Percentage': '875.0%',
#  'ETH-GBP Hold Final Value': '£135,060',
#  'ETH-GBP Hold Profit/Loss': '£130,063',
#  'ETH-GBP Hold Profit Percentage': '2603.0%'}

# %%
dic['backtest_details']
# Out:
# {'portfolio_value': [4996.5017491254375,
#   4885.708362561499,
#   5163.2032189817055,
#   5209.438892271251,
#   5210.700530488204,
#   5423.769225234575,
#   5724.737287213689,
#   5669.399859499206,
#   5539.20781801491,
#   5539.20781801491,
#   5535.332310296159,
#   5658.307312019802,
#   5618.745083932879,
#   6448.153316357232,
#   6449.902381657825,
#   6355.820784434767,
#   6355.820784434767,
#   6355.820784434767,
#   6355.820784434767,
#   6355.820784434767,
#   6355.820784434767,
#   6355.820784434767,
#   6355.820784434767,
#   6355.820784434767,
#   6355.820784434767,
#   6355.820784434767,
#   6351.373933311225,
#   6679.433040812776,
#   6621.0727824316355,
#   6725.106659357008,
#   6548.7053018466595,
#   6548.7053018466595,
#   6548.7053018466595,
#   6548.7053018466595,
#   6548.7053018466595,
#   6544.123499036772,
#   6838.5158252782885,
#   7186.523589759041,
#   7237.271994825156,
#   7419.225890369122,
#   7214.443452646469,
#   7449.189390646849,
#   7524.563647432263,
#   7548.310045452468,
#   8001.5962085861265,
#   7447.706849093624,
#   7447.706849093624,
#   7447.706849093624,
#   7447.706849093624,
#   7447.706849093624,
#   7447.706849093624,
#   7447.706849093624,
#   7447.706849093624,
#   7447.706849093624,
#   7442.496059693959,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7156.580166118919,
#   7151.573063553918,
#   7154.882745566399,
#   7356.418574505514,
#   7558.145583251896,
#   7556.848678761786,
#   7723.209521264446,
#   7664.45938084157,
#   8998.411472974649,
#   8805.670520624553,
#   8799.509631704577,
#   8656.849352210505,
#   8650.79258604704,
#   8644.10295695705,
#   8776.152282996762,
#   8573.09209226833,
#   8501.291554166311,
#   8309.314208219694,
#   9358.062593376595,
#   9312.934255002847,
#   10127.57370592254,
#   10036.7109312873,
#   9542.01860157212,
#   9651.483329712375,
#   9964.94032053439,
#   10377.443405928572,
#   10535.271215440998,
#   10561.829127835976,
#   10699.25220554148,
#   10630.96365163033,
#   10636.22032039024,
#   11946.565554990542,
#   11946.565554990542,
#   11946.565554990542,
#   11946.565554990542,
#   11946.565554990542,
#   11946.565554990542,
#   11938.20713831039,
#   11884.469519902059,
#   11876.154548723716,
#   11719.526785381086,
#   11423.31995866649,
#   10410.630474877067,
#   10410.630474877067,
#   10410.630474877067,
#   10410.630474877067,
#   10410.630474877067,
#   10410.630474877067,
#   10410.630474877067,
#   10410.630474877067,
#   

#   69528.50706309864,
#   69528.50706309864,
#   69528.50706309864,
#   69528.50706309864,
#   69528.50706309864,
#   69528.50706309864,
#   69528.50706309864,
#   69528.50706309864,
#   69528.50706309864,
#   69479.86143097054,
#   70827.3013667913,
#   72250.12934642057,
#   71598.38527036147,
#   71598.38527036147,
#   71598.38527036147,
#   71598.38527036147,
#   71598.38527036147,
#   71548.29144758362,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70053.96272693777,
#   70004.94945966254,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68703.52999664663,
#   68655.46155986737,
#   68995.51209419116,
#   65285.0201185729,
#   65285.0201185729,
#   65285.0201185729,
#   65285.0201185729,
#   65285.0201185729,
#   65285.0201185729,
#   65285.0201185729,
#   65239.343442827776,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65306.91609748334,
#   65261.22410221274,
#   65078.22920308191,
#   65539.59688299456,
#   70187.22131230122,
#   70121.19249535329,
#   73435.81038314095,
#   76533.28544978282,
#   75512.10831542383,
#   75512.10831542383,
#   75512.10831542383,
#   75512.10831542383,
#   75512.10831542383,
#   75512.10831542383,
#   75459.27625563291,
#   76346.24773144591,
#   77646.60813406183,
#   75912.16645163902,
#   81683.99755998574,
#   81683.99755998574,
#   81683.99755998574,
#   81683.99755998574,
#   81683.99755998574,
#   81683.99755998574,
#   81683.99755998574,
#   81683.99755998574,
#   81683.99755998574,
#   81626.84733680534,
#   86002.22758029251,
#   86084.29072507814,
#   84399.38003152583,
#   83248.58201213783,
#   83248.58201213783,
#   83248.58201213783,
#   83248.58201213783,
#   83248.58201213783,
#   83248.58201213783,
#   83248.58201213783,
#   83248.58201213783,
#   83248.58201213783,
#   83248.58201213783,
#   83190.33712717182,
#   84625.01893402147,
#   88429.93745240074,
#   89393.11072479773,
#   89115.14820556954,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88905.83053354382,
#   88843.62755366028,
#   92774.31806566856,
#   95745.25724178304,
#   95923.70571685935,
#   97919.01222050106,
#   97919.01222050106,
#   97919.01222050106,
#   97919.01222050106,
#   97919.01222050106,
#   97919.01222050106,
#   97919.01222050106,
#   97919.01222050106,
#   97919.01222050106,
#   97850.50316647372,
#   103592.66462613347,
#   103520.18600020814,
#   101459.3837375441,
#   101348.89312076839,
#   103796.74220993165,
#   ...],
#  'trades': [{'asset': 'BTC',
#    'action': 'buy',
#    'qty': 0.9195142591886539,
#    'price': 5436.566045654296,
#    'time_point': 0},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0.9195142591886539,
#    'price': 6025.263693115235,
#    'time_point': 8},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6247.588022216797,
#    'time_point': 9},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6149.120190917969,
#    'time_point': 10},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 50.596664550715126,
#    'price': 109.45583124160765,
#    'time_point': 10},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 50.596664550715126,
#    'price': 125.64251535797119,
#    'time_point': 15},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 131.1471926727295,
#    'time_point': 16},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 128.30123477172853,
#    'time_point': 18},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 128.4494150390625,
#    'time_point': 19},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 130.01801206207276,
#    'time_point': 20},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 127.9830955810547,
#    'time_point': 21},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 124.12124268341066,
#    'time_point': 22},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 124.65027490997315,
#    'time_point': 23},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 130.83582499694825,
#    'time_point': 26},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 0.9308409852280702,
#    'price': 6826.675792236328,
#    'time_point': 26},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0.9308409852280702,
#    'price': 7182.1576130371095,
#    'time_point': 27},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 49.323330348841104,
#    'price': 135.4890821456909,
#    'time_point': 27},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 49.323330348841104,
#    'price': 134.35901064300538,
#    'time_point': 28},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 0.9254404563459612,
#    'price': 7158.087020507812,
#    'time_point': 28},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0.9254404563459612,
#    'price': 7077.727432373047,
#    'time_point': 30},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7109.7807336425785,
#    'time_point': 31},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7085.623384765626,
#    'time_point': 32},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7147.491361083985,
#    'time_point': 33},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7042.168560546876,
#    'time_point': 34},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7394.09065600586,
#    'time_point': 35},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 41.639696836579716,
#    'price': 157.23927065277098,
#    'time_point': 35},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 41.639696836579716,
#    'price': 172.7436630859375,
#    'time_point': 37},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 0.9454188785478831,
#    'price': 7605.218189208984,
#    'time_point': 37},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0.9454188785478831,
#    'price': 7966.138961425781,
#    'time_point': 42},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 36.731588478383735,
#    'price': 204.9550874633789,
#    'time_point': 42},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 36.731588478383735,
#    'price': 202.80083157348633,
#    'time_point': 45},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 199.02760316467285,
#    'time_point': 46},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 204.69566615295412,
#    'time_point': 47},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 200.13238191986085,
#    'time_point': 50},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 204.82063415527344,
#    'time_point': 51},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 202.29978522491456,
#    'time_point': 52},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 205.09269959259035,
#    'time_point': 54},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 0.996819338645299,
#    'price': 7469.976774169922,
#    'time_point': 54},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0.996819338645299,
#    'price': 7180.851625732423,
#    'time_point': 55},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6831.252586914063,
#    'time_point': 56},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6812.085905517579,
#    'time_point': 57},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6798.321794921875,
#    'time_point': 63},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7006.933745361329,
#    'time_point': 64},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6824.657741455078,
#    'time_point': 66},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6188.440364746094,
#    'time_point': 67},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6058.264274414063,
#    'time_point': 68},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6124.160997070313,
#    'time_point': 69},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6169.553816650391,
#    'time_point': 70},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 3952.930505004883,
#    'time_point': 71},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 4532.13172631836,
#    'time_point': 72},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 4236.158693115234,
#    'time_point': 73},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 4085.755172729492,
#    'time_point': 75},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 4309.103647705078,
#    'time_point': 76},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 4504.6684140625,
#    'time_point': 77},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 5014.874609130859,
#    'time_point': 81},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 5197.258469238282,
#    'time_point': 89},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 66.5381281583707,
#    'price': 107.53456774520873,
#    'time_point': 89},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 66.5381281583707,
#    'price': 107.62738039779664,
#    'time_point': 90},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.3786487509930674,
#    'price': 5192.374186523437,
#    'time_point': 90},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.3786487509930674,
#    'price': 5486.27941381836,
#    'time_point': 93},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 65.23966319456416,
#    'price': 115.89003886413573,
#    'time_point': 93},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 65.23966319456416,
#    'price': 138.05271950531008,
#    'time_point': 96},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.5153001202662835,
#    'price': 5941.338325195312,
#    'time_point': 96},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.5153001202662835,
#    'price': 5812.33505444336,
#    'time_point': 97},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 5915.504147216797,
#    'time_point': 98},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 63.161211612924305,
#    'price': 139.38791168975828,
#    'time_point': 98},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 63.161211612924305,
#    'price': 137.08700082397462,
#    'time_point': 99},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 127.1854523048401,
#    'time_point': 100},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.5686238122626524,
#    'price': 5517.650512939453,
#    'time_point': 100},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.5686238122626524,
#    'price': 5301.969271240235,
#    'time_point': 105},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 67.87530772868432,
#    'price': 122.48149059677124,
#    'time_point': 105},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 67.87530772868432,
#    'price': 149.34284798431398,
#    'time_point': 108},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.7456159614029887,
#    'price': 5804.620097900391,
#    'time_point': 108},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.7456159614029887,
#    'price': 5754.843794921875,
#    'time_point': 109},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 69.00542143358324,
#    'price': 145.520874710083,
#    'time_point': 109},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 69.00542143358324,
#    'price': 138.4037554473877,
#    'time_point': 110},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.7252071108863782,
#    'price': 5533.706388427734,
#    'time_point': 110},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.7252071108863782,
#    'price': 6207.303975097657,
#    'time_point': 116},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 67.05347098841425,
#    'price': 159.6427697753906,
#    'time_point': 116},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 67.05347098841425,
#    'price': 158.68730976867676,
#    'time_point': 117},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.6940452588975539,
#    'price': 6278.627490966796,
#    'time_point': 117},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.6940452588975539,
#    'price': 7053.504198486328,
#    'time_point': 119},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6879.407696533203,
#    'time_point': 120},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7087.133371582032,
#    'time_point': 121},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7232.590391845703,
#    'time_point': 125},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 71.83265102860175,
#    'price': 166.27781476593017,
#    'time_point': 125},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 71.83265102860175,
#    'price': 165.47971875000002,
#    'time_point': 126},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 171.42285165405275,
#    'time_point': 127},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.4771645107214089,
#    'price': 8043.851947265624,
#    'time_point': 127},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.4771645107214089,
#    'price': 7049.122113281251,
#    'time_point': 130},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 6972.568612304688,
#    'time_point': 131},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7181.776944091797,
#    'time_point': 132},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7569.895287841798,
#    'time_point': 133},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7953.542723632813,
#    'time_point': 134},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7703.046940429688,
#    'time_point': 135},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7934.536606445313,
#    'time_point': 139},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 59.73182352315888,
#    'price': 174.2546558074951,
#    'time_point': 139},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 59.73182352315888,
#    'price': 163.45640840148926,
#    'time_point': 141},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 170.19943412780762,
#    'time_point': 142},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 171.45246940612793,
#    'time_point': 143},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.288667011593449,
#    'price': 7573.44156665039,
#    'time_point': 143},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.288667011593449,
#    'price': 7209.716580566406,
#    'time_point': 144},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 55.8975628002327,
#    'price': 166.14692049407958,
#    'time_point': 144},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 55.8975628002327,
#    'price': 168.1992140350342,
#    'time_point': 145},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 163.62720613861086,
#    'time_point': 146},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 170.20350618743896,
#    'time_point': 147},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 178.34097594451904,
#    'time_point': 148},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.2149712572632476,
#    'price': 7735.298822021484,
#    'time_point': 148},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.2149712572632476,
#    'price': 7643.2170070800785,
#    'time_point': 149},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 51.89628752016426,
#    'price': 178.86780107116698,
#    'time_point': 149},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 51.89628752016426,
#    'price': 186.98638557434083,
#    'time_point': 151},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 197.73974948883057,
#    'time_point': 152},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 188.47849803161623,
#    'time_point': 153},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 190.36062839508057,
#    'time_point': 156},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 190.92039170837404,
#    'time_point': 157},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 192.4948451766968,
#    'time_point': 158},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.2646864712060202,
#    'price': 7669.899439453125,
#    'time_point': 158},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.2646864712060202,
#    'price': 7667.721350341797,
#    'time_point': 159},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 50.10184534065157,
#    'price': 193.47361106872557,
#    'time_point': 159},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 50.10184534065157,
#    'price': 194.5530196762085,
#    'time_point': 161},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.2543044714197793,
#    'price': 7768.103302001953,
#    'time_point': 161},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.2543044714197793,
#    'price': 7408.824984375,
#    'time_point': 162},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7553.989670410157,
#    'time_point': 163},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7549.5543891601565,
#    'time_point': 164},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7501.115729980469,
#    'time_point': 165},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7474.705113769532,
#    'time_point': 166},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7574.981610595703,
#    'time_point': 167},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7549.417738769532,
#    'time_point': 168},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7553.476255371094,
#    'time_point': 171},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7529.847450683595,
#    'time_point': 172},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7714.642214111329,
#    'time_point': 173},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7500.140143798829,
#    'time_point': 175},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7453.649240722657,
#    'time_point': 176},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7424.672037353516,
#    'time_point': 177},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7327.361342041016,
#    'time_point': 178},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7404.508296142579,
#    'time_point': 179},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7462.8799746093755,
#    'time_point': 180},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7314.392243896485,
#    'time_point': 183},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7275.945168457031,
#    'time_point': 184},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7311.720728759766,
#    'time_point': 185},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7269.799805175781,
#    'time_point': 186},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7499.609647460938,
#    'time_point': 187},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 48.03561847566139,
#    'price': 193.3816156311035,
#    'time_point': 187},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 48.03561847566139,
#    'price': 190.81863597106934,
#    'time_point': 191},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.2458139308069813,
#    'price': 7354.569489990234,
#    'time_point': 191},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.2458139308069813,
#    'price': 7316.874888671876,
#    'time_point': 192},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7342.396301269531,
#    'time_point': 193},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7298.045440917969,
#    'time_point': 196},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7267.900852783204,
#    'time_point': 197},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7277.280437988282,
#    'time_point': 198},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7284.991424316407,
#    'time_point': 199},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 7302.9106828613285,
#    'time_point': 200},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 48.00947015455993,
#    'price': 189.7921142578125,
#    'time_point': 200},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 48.00947015455993,
#    'price': 192.34849504852295,
#    'time_point': 202},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.2529927660408031,
#    'price': 7367.046428466797,
#    'time_point': 202},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.2529927660408031,
#    'price': 7479.098423828125,
#    'time_point': 203},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 45.45742999157441,
#    'price': 206.07210076904295,
#    'time_point': 203},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 45.45742999157441,
#    'price': 241.8314468841553,
#    'time_point': 207},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.419048215829949,
#    'price': 7743.668727539062,
#    'time_point': 207},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.419048215829949,
#    'price': 8524.202563476563,
#    'time_point': 208},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 48.44191493216887,
#    'price': 249.60649136352538,
#    'time_point': 208},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 48.44191493216887,
#    'price': 290.66883238220214,
#    'time_point': 219},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.5824376495115442,
#    'price': 8894.456724609374,
#    'time_point': 219},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.5824376495115442,
#    'price': 9079.327206054688,
#    'time_point': 222},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 47.412639316361734,
#    'price': 302.90916087341304,
#    'time_point': 222},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 47.412639316361734,
#    'price': 291.29428244018555,
#    'time_point': 223},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.5783480437761275,
#    'price': 8746.807741699218,
#    'time_point': 223},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.5783480437761275,
#    'price': 8875.598066894532,
#    'time_point': 224},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 9012.254313964844,
#    'time_point': 225},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 42.66393841585748,
#    'price': 328.2205162811279,
#    'time_point': 225},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 42.66393841585748,
#    'price': 319.4876677093506,
#    'time_point': 230},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 309.8890453491211,
#    'time_point': 231},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 314.84381159973145,
#    'time_point': 232},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 297.1668329772949,
#    'time_point': 233},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 302.2553518981934,
#    'time_point': 234},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.525937036247177,
#    'price': 8929.038459960937,
#    'time_point': 234},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.525937036247177,
#    'price': 8904.456677246095,
#    'time_point': 235},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 9003.873740722656,
#    'time_point': 236},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 43.47493730483003,
#    'price': 312.4146131286621,
#    'time_point': 236},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 43.47493730483003,
#    'price': 291.8269139404297,
#    'time_point': 237},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.4667312003163404,
#    'price': 8646.49393798828,
#    'time_point': 237},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.4667312003163404,
#    'price': 8687.072259765626,
#    'time_point': 238},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 43.54008070242382,
#    'price': 292.52366065979004,
#    'time_point': 238},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 43.54008070242382,
#    'price': 289.7402197723389,
#    'time_point': 239},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 296.3638594207764,
#    'time_point': 240},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 252.34773152160645,
#    'time_point': 248},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 266.65969427490234,
#    'time_point': 249},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 285.36960343933106,
#    'time_point': 256},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 293.47062292480473,
#    'time_point': 257},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 283.1104186553955,
#    'time_point': 258},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 282.1294945678711,
#    'time_point': 259},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.4883291647356476,
#    'price': 8472.767469726563,
#    'time_point': 259},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.4883291647356476,
#    'price': 8469.105125976563,
#    'time_point': 261},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 42.32012639984856,
#    'price': 297.7253568878174,
#    'time_point': 261},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 42.32012639984856,
#    'price': 286.76053970336915,
#    'time_point': 263},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.4335933861292451,
#    'price': 8461.875307617187,
#    'time_point': 263},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.4335933861292451,
#    'price': 8157.297728759766,
#    'time_point': 264},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 8266.079736328125,
#    'time_point': 265},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 8314.84147607422,
#    'time_point': 271},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 42.35087174190635,
#    'price': 276.0172426300049,
#    'time_point': 271},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 42.35087174190635,
#    'price': 279.504983505249,
#    'time_point': 272},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.4029715101473754,
#    'price': 8433.916999511719,
#    'time_point': 272},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.4029715101473754,
#    'price': 8236.956609863282,
#    'time_point': 274},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 42.122581886182694,
#    'price': 274.237544631958,
#    'time_point': 274},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 42.122581886182694,
#    'price': 267.5316945800781,
#    'time_point': 275},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 267.7920623779297,
#    'time_point': 276},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 264.39944190979,
#    'time_point': 279},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.367902331266079,
#    'price': 8234.958194824218,
#    'time_point': 279},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.367902331266079,
#    'price': 8255.935396972656,
#    'time_point': 280},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 8477.32952734375,
#    'time_point': 282},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 40.261459437955665,
#    'price': 280.3871633148193,
#    'time_point': 282},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 40.261459437955665,
#    'price': 284.77550976562503,
#    'time_point': 293},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.2454499230390577,
#    'price': 9202.210133789062,
#    'time_point': 293},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.2454499230390577,
#    'price': 9909.321181152345,
#    'time_point': 295},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 38.97252150472901,
#    'price': 316.54680514526365,
#    'time_point': 295},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 38.97252150472901,
#    'price': 302.4829297027588,
#    'time_point': 299},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.1723941513384812,
#    'price': 10051.063059082031,
#    'time_point': 299},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.1723941513384812,
#    'price': 10472.898626464845,
#    'time_point': 300},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 39.56892457842791,
#    'price': 310.17912094116207,
#    'time_point': 300},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 39.56892457842791,
#    'price': 299.06212509155273,
#    'time_point': 301},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.1571582734408767,
#    'price': 10222.312703613281,
#    'time_point': 301},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.1571582734408767,
#    'price': 10481.2098984375,
#    'time_point': 306},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 40.8661070498038,
#    'price': 296.66559265136715,
#    'time_point': 306},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 40.8661070498038,
#    'price': 309.99894520568847,
#    'time_point': 308},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.1611239208460715,
#    'price': 10906.142729003906,
#    'time_point': 308},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.1611239208460715,
#    'price': 11851.286236328126,
#    'time_point': 309},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 43.62774865876671,
#    'price': 315.2880584106445,
#    'time_point': 309},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 43.62774865876671,
#    'price': 349.89951716613774,
#    'time_point': 315},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 1.28458258411187,
#    'price': 11878.740112792968,
#    'time_point': 315},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 1.28458258411187,
#    'price': 12398.503701660156,
#    'time_point': 316},
#   {'asset': 'ETH',
#    'action': 'buy',
# ...
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.321849801341907,
#    'price': 22489.183376953126,
#    'time_point': 1194},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22781.324342773438,
#    'time_point': 1195},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23918.138463867188,
#    'time_point': 1196},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 77.52850431842187,
#    'price': 1543.125180908203,
#    'time_point': 1196},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 77.52850431842187,
#    'price': 1677.101703491211,
#    'time_point': 1203},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.459078205068033,
#    'price': 23808.26537109375,
#    'time_point': 1203},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.459078205068033,
#    'price': 23179.623140625,
#    'time_point': 1205},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22693.84466699219,
#    'time_point': 1206},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21924.631809570314,
#    'time_point': 1207},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22359.148817382815,
#    'time_point': 1208},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22154.594895507813,
#    'time_point': 1209},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22009.261348632815,
#    'time_point': 1210},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22790.99138183594,
#    'time_point': 1211},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22779.26287402344,
#    'time_point': 1212},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23572.6296640625,
#    'time_point': 1213},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23295.098577148437,
#    'time_point': 1216},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22489.36687890625,
#    'time_point': 1217},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22975.871551757813,
#    'time_point': 1218},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23066.402435546875,
#    'time_point': 1219},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22916.29393359375,
#    'time_point': 1220},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22857.961786132815,
#    'time_point': 1222},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22518.391421875,
#    'time_point': 1223},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21946.59152734375,
#    'time_point': 1224},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21898.556962890627,
#    'time_point': 1225},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21865.823337890626,
#    'time_point': 1226},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 86.64007446845098,
#    'price': 1459.933703613281,
#    'time_point': 1226},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 86.64007446845098,
#    'price': 1445.3205573120117,
#    'time_point': 1230},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.784389538274908,
#    'price': 21639.724611328125,
#    'time_point': 1230},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.784389538274908,
#    'price': 21699.953189453125,
#    'time_point': 1231},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 86.42022234188535,
#    'price': 1451.8682715454102,
#    'time_point': 1231},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 86.42022234188535,
#    'price': 1460.4016360473634,
#    'time_point': 1232},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.82248261610813,
#    'price': 21667.347791015625,
#    'time_point': 1232},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.82248261610813,
#    'price': 21607.499439453128,
#    'time_point': 1234},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21593.7758359375,
#    'time_point': 1235},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21786.068313476564,
#    'time_point': 1236},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 85.93766039412967,
#    'price': 1463.374387939453,
#    'time_point': 1236},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 85.93766039412967,
#    'price': 1492.7676470947267,
#    'time_point': 1239},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.845139796773647,
#    'price': 21938.508694335935,
#    'time_point': 1239},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.845139796773647,
#    'price': 22459.96166699219,
#    'time_point': 1245},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 85.54938981457558,
#    'price': 1533.957269165039,
#    'time_point': 1245},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 85.54938981457558,
#    'price': 1505.1520767822267,
#    'time_point': 1247},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.882013808551531,
#    'price': 21882.529546874997,
#    'time_point': 1247},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.882013808551531,
#    'price': 21806.10906933594,
#    'time_point': 1251},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 84.25834682021284,
#    'price': 1521.6597416381835,
#    'time_point': 1251},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 84.25834682021284,
#    'price': 1456.6426522216798,
#    'time_point': 1252},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.917993554033192,
#    'price': 20730.879791015625,
#    'time_point': 1252},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.917993554033192,
#    'price': 21158.97771875,
#    'time_point': 1254},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21097.67244921875,
#    'time_point': 1255},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21064.187247070313,
#    'time_point': 1256},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20554.715547851563,
#    'time_point': 1257},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20610.256123046875,
#    'time_point': 1258},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20687.561201171877,
#    'time_point': 1259},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20549.155829101564,
#    'time_point': 1260},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 19818.806342773438,
#    'time_point': 1261},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 19994.829615234376,
#    'time_point': 1262},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20519.574923828128,
#    'time_point': 1263},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23500.968247070316,
#    'time_point': 1268},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 84.48866760535914,
#    'price': 1481.484024169922,
#    'time_point': 1268},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 84.48866760535914,
#    'price': 1492.2930310058593,
#    'time_point': 1272},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.260669548678002,
#    'price': 23957.296880859372,
#    'time_point': 1272},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.260669548678002,
#    'price': 24065.18794921875,
#    'time_point': 1274},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23786.772539062502,
#    'time_point': 1275},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23973.573623046876,
#    'time_point': 1277},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 83.13634850868294,
#    'price': 1522.1785556030272,
#    'time_point': 1277},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 83.13634850868294,
#    'price': 1539.8182067260743,
#    'time_point': 1280},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.2103665516884705,
#    'price': 24559.435690429687,
#    'time_point': 1280},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.2103665516884705,
#    'price': 23459.61783886719,
#    'time_point': 1283},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23621.985833007813,
#    'time_point': 1284},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23583.27472949219,
#    'time_point': 1285},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23490.131871093752,
#    'time_point': 1286},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 84.15378376789927,
#    'price': 1451.9171240844726,
#    'time_point': 1286},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 84.15378376789927,
#    'price': 1480.6954391479494,
#    'time_point': 1291},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.372673587333268,
#    'price': 23183.296792968747,
#    'time_point': 1291},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.372673587333268,
#    'price': 23130.911180664065,
#    'time_point': 1292},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23097.693422851564,
#    'time_point': 1293},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23050.224981445313,
#    'time_point': 1294},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22895.69681542969,
#    'time_point': 1295},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23146.329249023438,
#    'time_point': 1299},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23397.316973632813,
#    'time_point': 1300},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22761.2543046875,
#    'time_point': 1301},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22657.546418945312,
#    'time_point': 1302},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22696.831454101564,
#    'time_point': 1303},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22820.71088964844,
#    'time_point': 1304},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 85.38694321148186,
#    'price': 1454.849253479004,
#    'time_point': 1304},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 85.38694321148186,
#    'price': 1458.6692263183595,
#    'time_point': 1305},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.45221327531755,
#    'price': 22835.0368125,
#    'time_point': 1305},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.45221327531755,
#    'price': 22768.016546875002,
#    'time_point': 1308},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23181.739269531252,
#    'time_point': 1309},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22795.389572265627,
#    'time_point': 1312},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22770.327890625,
#    'time_point': 1313},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22768.809119140627,
#    'time_point': 1314},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22818.79778417969,
#    'time_point': 1315},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23147.176481445313,
#    'time_point': 1319},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 85.23332242904495,
#    'price': 1455.8441354370116,
#    'time_point': 1319},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 85.23332242904495,
#    'price': 1455.7790705566408,
#    'time_point': 1320},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.349698544444223,
#    'price': 23184.719378906248,
#    'time_point': 1320},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.349698544444223,
#    'price': 23056.579224609377,
#    'time_point': 1321},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 23170.701822265626,
#    'time_point': 1322},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22539.425821289064,
#    'time_point': 1324},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 86.86531313726687,
#    'price': 1419.3975765380858,
#    'time_point': 1324},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 86.86531313726687,
#    'price': 1321.1020579833985,
#    'time_point': 1325},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 0,
#    'price': 1303.6863317260743,
#    'time_point': 1326},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.60475375659815,
#    'price': 20466.919751953123,
#    'time_point': 1326},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.60475375659815,
#    'price': 20463.565833007815,
#    'time_point': 1329},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20437.069322265626,
#    'time_point': 1330},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20768.526557617188,
#    'time_point': 1331},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20662.464380859376,
#    'time_point': 1334},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20713.776602539063,
#    'time_point': 1335},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20690.93841796875,
#    'time_point': 1336},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21932.707847656253,
#    'time_point': 1337},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21463.63976464844,
#    'time_point': 1338},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20454.859250976562,
#    'time_point': 1339},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20487.678770507813,
#    'time_point': 1340},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20540.078338867188,
#    'time_point': 1341},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20620.766490234375,
#    'time_point': 1342},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20439.505603515627,
#    'time_point': 1343},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20594.732638671878,
#    'time_point': 1345},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21023.020340820312,
#    'time_point': 1346},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20772.315677734376,
#    'time_point': 1347},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20764.317725585937,
#    'time_point': 1348},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20674.296352539062,
#    'time_point': 1349},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20107.132810546875,
#    'time_point': 1350},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20670.8000546875,
#    'time_point': 1351},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 20989.601511718753,
#    'time_point': 1352},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21392.304356445315,
#    'time_point': 1356},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21594.669919921875,
#    'time_point': 1357},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21946.32603515625,
#    'time_point': 1358},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21999.076990234375,
#    'time_point': 1359},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21601.379454101563,
#    'time_point': 1360},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21702.709623046878,
#    'time_point': 1361},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21706.098552734376,
#    'time_point': 1362},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21438.896283203125,
#    'time_point': 1363},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21523.66442480469,
#    'time_point': 1364},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 21574.025950195315,
#    'time_point': 1365},
#   {'asset': 'ETH',
#    'action': 'buy',
#    'qty': 87.34865508878801,
#    'price': 1312.525930114746,
#    'time_point': 1365},
#   {'asset': 'ETH',
#    'action': 'sell',
#    'qty': 87.34865508878801,
#    'price': 1315.748046875,
#    'time_point': 1366},
#   {'asset': 'BTC',
#    'action': 'buy',
#    'qty': 5.287632508752239,
#    'price': 21726.70948828125,
#    'time_point': 1366},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 5.287632508752239,
#    'price': 22939.145783203126,
#    'time_point': 1370},
#   {'asset': 'BTC',
#    'action': 'sell',
#    'qty': 0,
#    'price': 22759.712107421878,
#    'time_point': 1371},
#   ...],
#  'final_positions': {'BTC': 0, 'ETH': 0},
#  'final_cash': 180044.65453140374}

# %%
plot_prices_positions_and_portfolio(dic)

# %%
################################################################################
################################PLOTSPLOTSPLOTS#################################
################################################################################

# %%
def plot(df):
    sns.lineplot(data=df, x='Date', y='Close')
    sns.lineplot(data=df, x='Date', y='short_sma')
    sns.lineplot(data=df, x='Date', y='long_sma')

# %%
plot(pd.DataFrame(dic['ETH-BTC']))

# %%
plot(pd.DataFrame(dic['BTC-GBP']))

# %%
plot(pd.DataFrame(dic['ETH-GBP']))

# %%
################################################################################
################################OLDOLDOLDOLDOLD#################################
################################################################################

# %%
################################################################################
################################OLDOLDOLDOLDOLD#################################
################################################################################

# %%
finviz = True
yahoo_extract = True
data_prep = False
meanreversion = False
strategy = False
risk_management = False
run_backtest = False
run_forwardstest = False
montecarlo = False

# %%
start_time = datetime.now()
print("start time: " + str(start_time))

input_vars = config()
df = master(input_vars, start_time, finviz=finviz, yahoo_extract=yahoo_extract, data_prep=data_prep, meanreversion=meanreversion, strategy=strategy, risk_management=risk_management, run_backtest=run_backtest, run_forwardstest=run_forwardstest, montecarlo=montecarlo)
# Out:
# start time: 2023-08-19 22:11:02.403995
# data extract between: 2022-01-01 and 2022-03-01
# 0: ^GSPC
# Process: Data extraction complete.
# data extract between: 2022-03-02 and 2022-04-30
# 0: ^GSPC
# Process: Data extraction complete.
# data extract between: 2022-05-01 and 2022-06-29
# 0: ^GSPC
# Process: Data extraction complete.
# data extract between: 2022-06-30 and 2022-08-28
# 0: ^GSPC
# Process: Data extraction complete.
# data extract between: 2022-08-29 and 2022-10-27
# 0: ^GSPC
# Process: Data extraction complete.
# data extract between: 2022-10-28 and 2022-12-26
# 0: ^GSPC
# Process: Data extraction complete.
# data extract between: 2022-12-27 and 2023-02-24
# 0: ^GSPC
# Process: Data extraction complete.
# data extract between: 2023-02-25 and 2023-04-25
# 0: ^GSPC
# Process: Data extraction complete.
# data extract between: 2023-04-26 and 2023-06-24
# 0: ^GSPC
# Process: Data extraction complete.
# data extract between: 2023-06-25 and 2023-08-19
# 0: ^GSPC
# Process: Data extraction complete.
# Process: Historic data saved to outputs/historic_001_1h.csv.
# changes successfully committed to historic_001_1h!

# %%
################################################################################
################################################################################
################################################################################

# %%
df.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume', 'ticker', 'dt'], dtype='object')

# %%
df.plot(x='dt',y='Close')
# Out:
# <Axes: xlabel='dt'>
