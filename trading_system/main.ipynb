# %%
from datetime import datetime
import matplotlib as plt
import seaborn as sns
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2
from config import AppConfig
from main import main
from backtesting.evaluate_plot import plot_prices_positions_and_portfolio

# %%
################################################################################
################################################################################
################################################################################

# %%
# Initialize the app configuration
config = AppConfig(system_mode='development')
# 
# Example usage
print(config.summary())
# Out:
# {'System Mode': 'development', 'Tickers': ['BTC-GBP', 'ETH-GBP', 'ETH-BTC'], 'Start Date': datetime.date(2024, 1, 1), 'End Date': datetime.date(2025, 6, 27), 'Database Path': 'outputs/mydatabase.db', 'File Path': '../outputs/'}

# %%
dic = main()
# Out:
# 2025-06-28 18:12:15 - root - INFO - Main System: Starting the trading system...
# 2025-06-28 18:12:15 - root - INFO - Main System: Config loaded successfully.
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/data/main.py:58: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(pair, start=start, end=end, interval="1d")
# [*********************100%***********************]  1 of 1 completed
# 2025-06-28 18:12:16 - root - INFO - Data fetched successfully for BTC-GBP.
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/data/main.py:58: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(pair, start=start, end=end, interval="1d")
# [*********************100%***********************]  1 of 1 completed
# 2025-06-28 18:12:16 - root - INFO - Data fetched successfully for ETH-GBP.
# /Users/hughdaman/PycharmProjects/daman-trading/trading_system/data/main.py:58: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(pair, start=start, end=end, interval="1d")
# [*********************100%***********************]  1 of 1 completed
# 2025-06-28 18:12:16 - root - INFO - Data fetched successfully for ETH-BTC.
# 2025-06-28 18:12:16 - root - INFO - Main System: Data loaded successfully.
# 2025-06-28 18:12:16 - root - INFO - Calculating indicators...
# 2025-06-28 18:12:16 - root - INFO - Complete: indicators...
# 2025-06-28 18:12:16 - root - INFO - Generating signals...
# 2025-06-28 18:12:16 - root - INFO - Signals generated for 3 assets.
# 2025-06-28 18:12:16 - root - INFO - Applying strategy...
# 2025-06-28 18:12:16 - root - INFO - Complete: strategy...
# 2025-06-28 18:12:16 - root - INFO - Strategy completed successfully.
# 2025-06-28 18:12:16 - root - INFO - Main System: Strategy signals generated successfully.
# 2025-06-28 18:12:16 - root - INFO - Main System: Backtesting completed successfully.
# 2025-06-28 18:12:16 - root - INFO - Main System: Completed successfully.

# %%
dic['evaluation_summary']
# Out:
# {'Number of Trading Days': 493,
#  'Number of Trades': 62,
#  'Average Trades Per Month': 4.0,
#  'Start Portfolio Value': '£1,000',
#  'End Portfolio Value': '£446',
#  'Profit/Loss': '£-554',
#  'Profit Percentage': '-55.0%',
#  'Sharpe Ratio': -1.45,
#  'Sortino Ratio': -1.46,
#  'Volatility': '26.7%',
#  'Max Drawdown': '-63.4%',
#  'Average Drawdown Length': '60.88 days',
#  'Fees Paid': '£0.00',
#  'Win Rate': '50.0%',
#  'Profit Factor': inf,
#  'BTC-GBP Hold Final Value': '£1,906',
#  'BTC-GBP Hold Profit/Loss': '£906',
#  'BTC-GBP Hold Profit Percentage': '91.0%',
#  'ETH-GBP Hold Final Value': '£756',
#  'ETH-GBP Hold Profit/Loss': '£-244',
#  'ETH-GBP Hold Profit Percentage': '-24.0%'}

# %%
plot_prices_positions_and_portfolio(dic)

# %%
portfolio_values_df = pd.DataFrame(dic['backtest_details']['portfolio_value'], columns=['Portfolio Value'])
sns.lineplot(portfolio_values_df)
# Out:
# <Axes: >

# %%
################################################################################
################################PLOTSPLOTSPLOTS#################################
################################################################################

# %%
def plot(df):
    sns.lineplot(data=df, x='Date', y='Close')
    sns.lineplot(data=df, x='Date', y='short_sma')
    sns.lineplot(data=df, x='Date', y='long_sma')

# %%
plot(pd.DataFrame(dic['ETH-BTC']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 plot(pd.DataFrame(dic['ETH-BTC']))
#
# Cell In[42], line 3, in plot(df)
#       1 def plot(df):
#       2     sns.lineplot(data=df, x='Date', y='Close')
# ----> 3     sns.lineplot(data=df, x='Date', y='short_sma')
#       4     sns.lineplot(data=df, x='Date', y='long_sma')
#
# File ~/PycharmProjects/daman-trading/venv/lib/python3.11/site-packages/seaborn/relational.py:618, in lineplot(data, x, y, hue, size, style, units, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     615 errorbar = _deprecate_ci(errorbar, ci)
#     617 variables = _LinePlotter.get_semantics(locals())
# --> 618 p = _LinePlotter(
#     619     data=data, variables=variables,
#     620     estimator=estimator, n_boot=n_boot, seed=seed, errorbar=errorbar,
#     621     sort=sort, orient=orient, err_style=err_style, err_kws=err_kws,
#     622     legend=legend,
#     623 )
#     625 p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#     626 p.map_size(sizes=sizes, order=size_order, norm=size_norm)
#
# File ~/PycharmProjects/daman-trading/venv/lib/python3.11/site-packages/seaborn/relational.py:365, in _LinePlotter.__init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
#     351 def __init__(
#     352     self, *,
#     353     data=None, variables={},
#    (...)
#     359     # the kind of plot to draw, but for the time being we need to set
#     360     # this information so the SizeMapping can use it
#     361     self._default_size_range = (
#     362         np.r_[.5, 2] * mpl.rcParams["lines.linewidth"]
#     363     )
# --> 365     super().__init__(data=data, variables=variables)
#     367     self.estimator = estimator
#     368     self.errorbar = errorbar
#
# File ~/PycharmProjects/daman-trading/venv/lib/python3.11/site-packages/seaborn/_oldcore.py:640, in VectorPlotter.__init__(self, data, variables)
#     635 # var_ordered is relevant only for categorical axis variables, and may
#     636 # be better handled by an internal axis information object that tracks
#     637 # such information and is set up by the scale_* methods. The analogous
#     638 # information for numeric axes would be information about log scales.
#     639 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640 self.assign_variables(data, variables)
#     642 for var, cls in self._semantic_mappings.items():
#     643
#     644     # Create the mapping function
#     645     map_func = partial(cls.map, plotter=self)
#
# File ~/PycharmProjects/daman-trading/venv/lib/python3.11/site-packages/seaborn/_oldcore.py:701, in VectorPlotter.assign_variables(self, data, variables)
#     699 else:
#     700     self.input_format = "long"
# --> 701     plot_data, variables = self._assign_variables_longform(
#     702         data, **variables,
#     703     )
#     705 self.plot_data = plot_data
#     706 self.variables = variables
#
# File ~/PycharmProjects/daman-trading/venv/lib/python3.11/site-packages/seaborn/_oldcore.py:938, in VectorPlotter._assign_variables_longform(self, data, **kwargs)
#     933 elif isinstance(val, (str, bytes)):
#     934
#     935     # This looks like a column name but we don't know what it means!
#     937     err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938     raise ValueError(err)
#     940 else:
#     941
#     942     # Otherwise, assume the value is itself data
#     943
#     944     # Raise when data object is present and a vector can't matched
#     945     if isinstance(data, pd.DataFrame) and not isinstance(val, pd.Series):
#
# ValueError: Could not interpret value `short_sma` for parameter `y`

# %%
plot(pd.DataFrame(dic['BTC-GBP']))

# %%
plot(pd.DataFrame(dic['ETH-GBP']))

# %%
dic.keys()

# %%
dic['backtest_details']['trades']

# %%
dic['combined_position']

# %%
dic.keys()
# Out:
# dict_keys(['BTC-GBP', 'ETH-GBP', 'ETH-BTC', 'combined_position', 'backtest_details', 'evaluation_summary'])
